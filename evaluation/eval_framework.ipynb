# %%
import numpy as np
import pandas as pd
import datetime
import random
import pytz
from datetime import datetime, timedelta
import random
from watttime import WattTimeMyAccess, WattTimeHistorical, WattTimeForecast, WattTimeMaps

# %%
# utilities and functions

def generate_random_plug_time(date):
    """
    Generate a random datetime ona the given date, uniformly distributed between 5pm and 9 pm.

    Parameters:
    date (datetime.date): The date on which to generate the random time.

    Returns:
    - datetime: A datetime object for the given date with a random time between 5 PM and 9 PM
    """
    #  Define the start and end times for the interval (5 PM to 9PM)
    start_time = datetime.combine(date, datetime.strptime("17:00:00", "%H:%M:%S").time())
    end_time = datetime.combine(date, datetime.strptime("21:00:00", "%H:%M:%S").time())
    
    # Calculate the total number of seconds between start and end times 
    total_seconds = int((end_time - start_time).total_seconds())
    
    # Generate a random number of seconds within the interval
    total_seconds = random.randint(0, total_seconds)

    # Add the random seconds to the start time to get the random datetime
    random_datetime = start_time + timedelta(seconds=total_seconds)

    random_datetime_utc = pytz.utc.localize(random_datetime)

    return random_datetime_utc

def generate_random_unplug_time(random_plug_time,mean,stddev):
    """ 
    Adds a number of sconds drawn from a normal distribution to the given datetime.

    Parameters:
    -datetime_obj
    -mean
    -stddev

    REturns 
    -pd.Timestamp: the new datetime after adding the random seconds
    """
    random_seconds = np.random.normal(loc=mean,scale=stddev)

    #convert to timedelta
    random_timedelta = timedelta(seconds=random_seconds)
    new_datetime = random_plug_time + random_timedelta

    if not isinstance(new_datetime,pd.Timestamp):
        new_datetime = pd.Timestamp(new_datetime)
    return new_datetime

# %% [markdown]
# # Get data

# %%
username = ""
password = ""
# region = 'PJM_NJ'

start = '2023-02-15 00:00Z'
end = '2023-03-15 00:00Z'

wt_myaccess = WattTimeMyAccess(username, password)
wt_hist = WattTimeHistorical(username, password)

access_df = wt_myaccess.get_access_pandas()

moers = pd.DataFrame([[pd.to_datetime(start, utc=True)]],columns=['point_time'])

# moers = pd.DataFrame(columns=['point_time')
moer_regions = access_df.loc[access_df['signal_type'] == 'co2_moer', 'region'].unique()
print(moer_regions)
# sampling to see if it works with a smaller dataset
moer_regions = moer_regions[:5]
for region in moer_regions:
    region_df = wt_hist.get_historical_pandas(
        start = start,
        end = end,
        region = region,
        signal_type = 'co2_moer'
    )
    region_df.rename(columns={'value':region}, inplace=True)
    # moers = pd.concat([moers, region_df], axis='rows')
    moers = pd.merge(moers, region_df, how="outer", on=["point_time"])
# Out:
# ['AECI' 'AESO' 'AT' 'AVA' 'AZPS' 'BANC' 'BCHYDRO' 'BE' 'BPA' 'BRA'
#  'CAISO_ESCONDIDO' 'CAISO_LONGBEACH' 'CAISO_NORTH' 'CAISO_PALMSPRINGS'
#  'CAISO_REDDING' 'CAISO_SANBERNARDINO' 'CAISO_SANDIEGO' 'CHL' 'CHPD'
#  'CPLE' 'CPLW' 'CZ' 'DE' 'DK' 'DOPD' 'DUK' 'EE' 'ELE' 'ERCOT_AUSTIN'
#  'ERCOT_COAST' 'ERCOT_EASTTX' 'ERCOT_HIDALGO' 'ERCOT_NORTHCENTRAL'
#  'ERCOT_PANHANDLE' 'ERCOT_SANANTONIO' 'ERCOT_SECOAST' 'ERCOT_SOUTHTX'
#  'ERCOT_WESTTX' 'ES' 'FI' 'FMPP' 'FPC' 'FPL' 'FR' 'GCPD' 'GR' 'GVL' 'HQ'
#  'HST' 'HU' 'IE' 'IESO_NORTH' 'IESO_SOUTH' 'IESO_WEST' 'IID' 'IND' 'IPCO'
#  'ISONE_CT' 'ISONE_ME' 'ISONE_NEMA' 'ISONE_NH' 'ISONE_RI' 'ISONE_SEMA'
#  'ISONE_VT' 'ISONE_WCMA' 'IT' 'JEA' 'JP_CB' 'JP_CG' 'JP_HKD' 'JP_HR'
#  'JP_KN' 'JP_KY' 'JP_ON' 'JP_SK' 'JP_TH' 'JP_TK' 'KOR' 'LDWP' 'LGEE' 'LT'
#  'LV' 'MISO_BEAUMONT' 'MISO_DETROIT' 'MISO_EAU_CLAIRE' 'MISO_GRAND_RAPIDS'
#  'MISO_INDIANAPOLIS' 'MISO_LAFAYETTE' 'MISO_LOWER_MS_RIVER' 'MISO_MADISON'
#  'MISO_MASON_CITY' 'MISO_MINNEAPOLIS' 'MISO_NEW_ORLEANS' 'MISO_N_DAKOTA'
#  'MISO_SAINT_LOUIS' 'MISO_SPRINGFIELD' 'MISO_UPPER_PENINSULA'
#  'MISO_WORTHINGTON' 'MPCO' 'MX_SIN' 'MYS' 'NEM_NSW' 'NEM_QLD' 'NEM_SA'
#  'NEM_TAS' 'NEM_VIC' 'NEVP' 'NIC' 'NL' 'NO' 'NYISO_CAPITAL'
#  'NYISO_CENTRAL' 'NYISO_HUDSON' 'NYISO_LONG' 'NYISO_MOHAWK' 'NYISO_NORTH'
#  'NYISO_NYC' 'NYISO_WEST' 'PACE' 'PACW' 'PER' 'PGE' 'PHL' 'PJM_CHICAGO'
#  'PJM_DC' 'PJM_EASTERN_KY' 'PJM_EASTERN_OH' 'PJM_NJ' 'PJM_ROANOKE'
#  'PJM_SOUTHWEST_OH' 'PJM_WESTERN_KY' 'PL' 'PNM' 'PSCO' 'PSEI' 'PT' 'RO'
#  'RS' 'SC' 'SCEG' 'SCL' 'SE' 'SEC' 'SGP' 'SI' 'SK' 'SOCO' 'SPA'
#  'SPP_FORTPECK' 'SPP_KANSAS' 'SPP_KC' 'SPP_MEMPHIS' 'SPP_ND' 'SPP_OKCTY'
#  'SPP_SIOUX' 'SPP_SPRINGFIELD' 'SPP_SWOK' 'SPP_TX' 'SPP_WESTNE' 'SRP'
#  'TAL' 'TEC' 'TEPC' 'TID' 'TPWR' 'TUR' 'TVA' 'UK' 'WACM' 'WALC' 'WAUW'
#  'WEM']

# %% [markdown]
# # Single user problem

# %%
# to characterize a single user you need four parameters
# rate= 11 #7.4, 11, or 22 kWh
# total_capacity= 118 #ranges from 21kW to 123 kW
# mean_length_charge = 36000 
# std_length_charge = 7200

# %% [markdown]
# ### Single user/single day problem

# %% [markdown]
# For each user-day, the following dataframe summarizes their relationship with the grid:
# 1. plug_in_time : random number from a uniform distribution between 5 and 9 pm, when the user plugs in their EV
# 2. unplug_time : random number from a normal distribution with inital mean given by user (example here is 10 hours, stddev is 3 hrs)
# 3. inital_charge : what percentage of battery was full at plug in time
# 4. total seconds to 95% : how long would it take to charge the battery to the desired level
# 5. length of interval : plug_in_time - unplug_time
# 6. final battery level : how charged was the battery in the end
# 7. uncharged: boolean is the battery more than 80% full at unplug time
# 8. MOER: sum of MOER in the grid for that day (number to minimize)

# %% [markdown]
# ### Data for single grid

# %%
df = moers[['point_time','AESO']].copy()
df.columns = ['point_time','values']
distinct_dates = df['point_time'].dt.date.unique()
distinct_dates_utc = [pd.Timestamp(date).replace(tzinfo=pytz.UTC) for date in distinct_dates]

# %% [markdown]
# # Simulate 1K users to get a distribution

# %%
all_users = pd.DataFrame()
for i in range(1000):
    # User is defined by 4 parmeters, rate, capacity, avg plug time, and std dev plug time
    rate = random.choice([11,7.4,22])
    total_capacity =  round(random.uniform(21,123))
    mean_length_charge = round(random.uniform(20000,30000))
    std_length_charge = round(random.uniform(6800,8000))
    
    print(f"working on user with {total_capacity} total_capacity, {rate} rate of charge, and ({mean_length_charge/3600},{std_length_charge/3600}) charging behavior.") 
    # This generates a dataset that,per user, gets every session (distinct days from the 5 minute interval dataset from MOERS)
    user_df = pd.DataFrame(distinct_dates_utc, columns=['distinct_dates']).sort_values(by='distinct_dates').copy() 
    # Unique user type given by the convo of 4 variables. 
    user_df['user_type'] =  'r'+str(rate)+'_tc'+str(total_capacity)+'_avglc'+str(mean_length_charge)+'_sdlc'+str(std_length_charge)
    # Generate plug and unplug time by using apply in the previous dataset and using the two helper functions defined above that generate intervals from normal distribuitons with user params
    user_df['plug_in_time'] = user_df['distinct_dates'].apply(generate_random_plug_time)
    user_df['unplug_time'] = user_df['plug_in_time'].apply(lambda x: generate_random_unplug_time(x,mean_length_charge,std_length_charge))
    
    # Another random parameter, this time at the session level, it's the initial charge of the battery.
    user_df['initial_charge'] = user_df.apply(lambda _: random.uniform(0.2,0.6), axis=1)
    user_df['total_seconds_to_95'] = user_df['initial_charge'].apply(lambda x: total_capacity*(0.95-x)/(rate/3600))
    
    # What time will the battery reach 95% 
    user_df['full_charge_time']= user_df['plug_in_time'] + pd.to_timedelta(user_df['total_seconds_to_95'],unit='s')
    user_df['length_plugged_in'] = (user_df.unplug_time - user_df.plug_in_time) / pd.Timedelta(seconds=1)

    # what happened first? did the user unplug or did it reach 95%
    user_df['session_charge'] = user_df[['total_seconds_to_95','length_plugged_in']].min(axis=1)*(rate/3600)
    user_df['final_perc_charged'] = user_df.session_charge.apply(lambda x: x/total_capacity)
    user_df['final_perc_charged'] = user_df.final_perc_charged + user_df.initial_charge

    # when did the device stop pulling power from the grid?
    user_df['final_charge_time'] = user_df[['full_charge_time', 'unplug_time']].min(axis=1)
    user_df['uncharged'] = np.where(user_df['final_perc_charged'] <0.80, True, False)

    # Join with MOER data, cross join every user session with the MOER data and then only keep those intervals where it was pulling power from the grid
    moer_temp = user_df[['user_type','distinct_dates','plug_in_time','final_charge_time']].copy()
    moer_temp['key'] = 1
    df['key'] = 1
    
    # This is the join, joining by key=1 does the cross join part
    moer_temp = pd.merge(moer_temp,df, on='key').drop(columns='key')
    moer_temp = moer_temp[(moer_temp['point_time']>moer_temp['plug_in_time'])&(moer_temp['point_time']<moer_temp['final_charge_time'])]

    # Add all the emissions that the user was generating at the time. This part needs to be modified at @Cindy's suggestion 
    moer_temp = moer_temp.groupby(['distinct_dates','user_type']).agg(
        sum_moer=('values','sum'),
        count_moer_intervals=('values','count'),
        avg_moer=('values','mean')
    ).reset_index()

    user_df= pd.merge(user_df,moer_temp, on=['user_type','distinct_dates'])
    all_users = pd.concat([all_users, user_df], axis=0)
    print(all_users.shape)
# Out:
# working on user with 73 total_capacity, 22 rate of charge, and (5.574166666666667,2.1475) charging behavior.
# (28, 15)
# working on user with 53 total_capacity, 22 rate of charge, and (7.924166666666666,1.9466666666666668) charging behavior.
# (56, 15)
# working on user with 38 total_capacity, 11 rate of charge, and (7.812777777777778,2.1997222222222224) charging behavior.
# (84, 15)
# working on user with 65 total_capacity, 7.4 rate of charge, and (7.291111111111111,2.042222222222222) charging behavior.
# (112, 15)
# working on user with 76 total_capacity, 22 rate of charge, and (7.388888888888889,1.8969444444444445) charging behavior.
# (140, 15)
# working on user with 109 total_capacity, 7.4 rate of charge, and (8.065,1.9625) charging behavior.
# (168, 15)
# working on user with 72 total_capacity, 11 rate of charge, and (6.514166666666667,1.9241666666666666) charging behavior.
# (196, 15)
# working on user with 122 total_capacity, 22 rate of charge, and (5.8677777777777775,1.9291666666666667) charging behavior.
# (224, 15)
# working on user with 29 total_capacity, 11 rate of charge, and (6.146388888888889,2.205277777777778) charging behavior.
# (252, 15)
# working on user with 67 total_capacity, 7.4 rate of charge, and (7.029166666666667,1.896111111111111) charging behavior.
# (280, 15)
# working on user with 78 total_capacity, 11 rate of charge, and (5.947777777777778,1.9077777777777778) charging behavior.
# (308, 15)
# working on user with 58 total_capacity, 22 rate of charge, and (5.7347222222222225,1.9713888888888889) charging behavior.
# (336, 15)
# working on user with 79 total_capacity, 7.4 rate of charge, and (7.291388888888889,2.11) charging behavior.
# (364, 15)
# working on user with 50 total_capacity, 11 rate of charge, and (7.986944444444444,1.9427777777777777) charging behavior.
# (392, 15)
# working on user with 104 total_capacity, 22 rate of charge, and (6.050833333333333,1.8936111111111111) charging behavior.
# (420, 15)
# working on user with 120 total_capacity, 7.4 rate of charge, and (7.990277777777778,2.158333333333333) charging behavior.
# (448, 15)
# working on user with 87 total_capacity, 11 rate of charge, and (7.871388888888889,2.088888888888889) charging behavior.
# (476, 15)
# working on user with 87 total_capacity, 11 rate of charge, and (5.743888888888889,2.1569444444444446) charging behavior.
# (504, 15)
# working on user with 122 total_capacity, 7.4 rate of charge, and (7.479722222222223,2.0383333333333336) charging behavior.
# (532, 15)
# working on user with 53 total_capacity, 11 rate of charge, and (7.9991666666666665,2.175) charging behavior.
# (560, 15)
# working on user with 71 total_capacity, 11 rate of charge, and (6.101388888888889,2.161111111111111) charging behavior.
# (588, 15)
# working on user with 65 total_capacity, 22 rate of charge, and (7.523333333333333,2.108888888888889) charging behavior.
# (616, 15)
# working on user with 52 total_capacity, 11 rate of charge, and (8.210277777777778,1.9722222222222223) charging behavior.
# (644, 15)
# working on user with 95 total_capacity, 22 rate of charge, and (6.565555555555555,2.1505555555555556) charging behavior.
# (672, 15)
# working on user with 57 total_capacity, 11 rate of charge, and (6.280555555555556,2.1038888888888887) charging behavior.
# (700, 15)
# working on user with 110 total_capacity, 11 rate of charge, and (6.569166666666667,2.0416666666666665) charging behavior.
# (728, 15)
# working on user with 116 total_capacity, 22 rate of charge, and (6.822222222222222,2.0980555555555553) charging behavior.
# (756, 15)
# working on user with 63 total_capacity, 22 rate of charge, and (6.19,2.1327777777777777) charging behavior.
# (784, 15)
# working on user with 82 total_capacity, 7.4 rate of charge, and (6.030277777777778,2.1491666666666664) charging behavior.
# (812, 15)
# working on user with 41 total_capacity, 11 rate of charge, and (7.596111111111111,1.9669444444444444) charging behavior.
# (840, 15)
# working on user with 92 total_capacity, 22 rate of charge, and (6.041666666666667,1.9958333333333333) charging behavior.
# (867, 15)
# working on user with 64 total_capacity, 22 rate of charge, and (6.561944444444444,2.173888888888889) charging behavior.
# (895, 15)
# working on user with 79 total_capacity, 7.4 rate of charge, and (7.751666666666667,1.9683333333333333) charging behavior.
# (923, 15)
# working on user with 69 total_capacity, 7.4 rate of charge, and (7.760833333333333,2.167222222222222) charging behavior.
# (951, 15)
# working on user with 105 total_capacity, 7.4 rate of charge, and (5.9863888888888885,2.0280555555555555) charging behavior.
# (979, 15)
# working on user with 49 total_capacity, 7.4 rate of charge, and (5.659722222222222,2.1219444444444444) charging behavior.
# (1007, 15)
# working on user with 121 total_capacity, 22 rate of charge, and (8.028888888888888,2.0388888888888888) charging behavior.
# (1035, 15)
# working on user with 87 total_capacity, 11 rate of charge, and (6.258611111111111,2.0477777777777777) charging behavior.
# (1063, 15)
# working on user with 78 total_capacity, 11 rate of charge, and (5.7347222222222225,2.175) charging behavior.
# (1090, 15)
# working on user with 26 total_capacity, 22 rate of charge, and (7.184444444444445,2.2030555555555558) charging behavior.
# (1118, 15)
# working on user with 31 total_capacity, 11 rate of charge, and (8.194444444444445,1.9213888888888888) charging behavior.
# (1146, 15)
# working on user with 53 total_capacity, 11 rate of charge, and (7.462777777777778,2.026666666666667) charging behavior.
# (1174, 15)
# working on user with 45 total_capacity, 11 rate of charge, and (5.558333333333334,2.1719444444444442) charging behavior.
# (1202, 15)
# working on user with 23 total_capacity, 11 rate of charge, and (8.18361111111111,2.101111111111111) charging behavior.
# (1230, 15)
# working on user with 56 total_capacity, 7.4 rate of charge, and (6.051388888888889,1.9591666666666667) charging behavior.
# (1258, 15)
# working on user with 73 total_capacity, 22 rate of charge, and (7.794444444444444,2.0475) charging behavior.
# (1286, 15)
# working on user with 103 total_capacity, 7.4 rate of charge, and (6.748888888888889,1.9755555555555555) charging behavior.
# (1314, 15)
# working on user with 75 total_capacity, 7.4 rate of charge, and (7.321944444444444,1.9430555555555555) charging behavior.
# (1342, 15)
# working on user with 107 total_capacity, 11 rate of charge, and (7.910555555555556,2.0030555555555556) charging behavior.
# (1370, 15)
# working on user with 106 total_capacity, 7.4 rate of charge, and (7.276111111111111,2.0305555555555554) charging behavior.
# (1398, 15)
# working on user with 80 total_capacity, 7.4 rate of charge, and (5.563055555555556,2.2133333333333334) charging behavior.
# (1426, 15)
# working on user with 99 total_capacity, 7.4 rate of charge, and (7.048055555555556,1.9483333333333333) charging behavior.
# (1454, 15)
# working on user with 105 total_capacity, 7.4 rate of charge, and (8.329722222222221,1.896111111111111) charging behavior.
# (1482, 15)
# working on user with 61 total_capacity, 11 rate of charge, and (7.421666666666667,1.933888888888889) charging behavior.
# (1510, 15)
# working on user with 70 total_capacity, 7.4 rate of charge, and (8.293611111111112,2.0122222222222224) charging behavior.
# (1538, 15)
# working on user with 46 total_capacity, 7.4 rate of charge, and (5.749444444444444,2.194166666666667) charging behavior.
# (1565, 15)
# working on user with 38 total_capacity, 7.4 rate of charge, and (8.179444444444444,1.9836111111111112) charging behavior.
# (1593, 15)
# working on user with 36 total_capacity, 11 rate of charge, and (7.343333333333334,1.9169444444444443) charging behavior.
# (1621, 15)
# working on user with 30 total_capacity, 22 rate of charge, and (5.885,2.1) charging behavior.
# (1649, 15)
# working on user with 110 total_capacity, 11 rate of charge, and (6.346388888888889,2.075) charging behavior.
# (1677, 15)
# working on user with 103 total_capacity, 22 rate of charge, and (6.543888888888889,2.182777777777778) charging behavior.
# (1705, 15)
# working on user with 53 total_capacity, 11 rate of charge, and (5.955277777777778,1.9697222222222222) charging behavior.
# (1733, 15)
# working on user with 51 total_capacity, 22 rate of charge, and (8.012777777777778,2.002222222222222) charging behavior.
# (1761, 15)
# working on user with 99 total_capacity, 7.4 rate of charge, and (7.703888888888889,2.115) charging behavior.
# (1789, 15)
# working on user with 32 total_capacity, 11 rate of charge, and (6.965833333333333,2.2047222222222222) charging behavior.
# (1817, 15)
# working on user with 53 total_capacity, 7.4 rate of charge, and (6.606944444444444,2.1791666666666667) charging behavior.
# (1845, 15)
# working on user with 74 total_capacity, 7.4 rate of charge, and (7.806388888888889,2.188888888888889) charging behavior.
# (1873, 15)
# working on user with 28 total_capacity, 7.4 rate of charge, and (7.064444444444445,2.1483333333333334) charging behavior.
# (1901, 15)
# working on user with 93 total_capacity, 11 rate of charge, and (7.618333333333333,2.0941666666666667) charging behavior.
# (1929, 15)
# working on user with 104 total_capacity, 7.4 rate of charge, and (6.276666666666666,2.180277777777778) charging behavior.
# (1957, 15)
# working on user with 63 total_capacity, 11 rate of charge, and (6.474722222222222,2.118333333333333) charging behavior.
# (1984, 15)
# working on user with 90 total_capacity, 22 rate of charge, and (7.141111111111111,2.0052777777777777) charging behavior.
# (2012, 15)
# working on user with 27 total_capacity, 11 rate of charge, and (7.7844444444444445,2.138333333333333) charging behavior.
# (2040, 15)
# working on user with 27 total_capacity, 11 rate of charge, and (5.986944444444444,2.126388888888889) charging behavior.
# (2068, 15)
# working on user with 30 total_capacity, 11 rate of charge, and (7.0488888888888885,1.9055555555555554) charging behavior.
# (2096, 15)
# working on user with 80 total_capacity, 7.4 rate of charge, and (5.695555555555556,2.0875) charging behavior.
# (2124, 15)
# working on user with 104 total_capacity, 11 rate of charge, and (6.828611111111111,1.9661111111111111) charging behavior.
# (2152, 15)
# working on user with 105 total_capacity, 7.4 rate of charge, and (6.902777777777778,2.1919444444444443) charging behavior.
# (2180, 15)
# working on user with 83 total_capacity, 11 rate of charge, and (7.982222222222222,2.155) charging behavior.
# (2208, 15)
# working on user with 87 total_capacity, 11 rate of charge, and (8.0775,1.9269444444444443) charging behavior.
# (2236, 15)
# working on user with 36 total_capacity, 7.4 rate of charge, and (6.993333333333333,2.078611111111111) charging behavior.
# (2264, 15)
# working on user with 44 total_capacity, 22 rate of charge, and (8.100277777777778,2.0019444444444443) charging behavior.
# (2292, 15)
# working on user with 76 total_capacity, 11 rate of charge, and (7.950277777777778,2.0844444444444443) charging behavior.
# (2320, 15)
# working on user with 80 total_capacity, 11 rate of charge, and (6.875277777777778,2.0008333333333335) charging behavior.
# (2348, 15)
# working on user with 25 total_capacity, 7.4 rate of charge, and (6.879722222222222,1.9388888888888889) charging behavior.
# (2376, 15)
# working on user with 55 total_capacity, 11 rate of charge, and (5.941111111111111,2.216111111111111) charging behavior.
# (2404, 15)
# working on user with 107 total_capacity, 11 rate of charge, and (7.9847222222222225,2.17) charging behavior.
# (2432, 15)
# working on user with 83 total_capacity, 7.4 rate of charge, and (6.585555555555556,2.120277777777778) charging behavior.
# (2460, 15)
# working on user with 105 total_capacity, 7.4 rate of charge, and (6.065555555555555,1.9419444444444445) charging behavior.
# (2488, 15)
# working on user with 104 total_capacity, 22 rate of charge, and (6.4558333333333335,1.9388888888888889) charging behavior.
# (2516, 15)
# working on user with 63 total_capacity, 22 rate of charge, and (5.635555555555555,1.9408333333333334) charging behavior.
# (2543, 15)
# working on user with 81 total_capacity, 11 rate of charge, and (6.584444444444444,2.1483333333333334) charging behavior.
# (2571, 15)
# working on user with 82 total_capacity, 22 rate of charge, and (8.193888888888889,1.9697222222222222) charging behavior.
# (2599, 15)
# working on user with 111 total_capacity, 11 rate of charge, and (5.988888888888889,2.075) charging behavior.
# (2627, 15)
# working on user with 83 total_capacity, 7.4 rate of charge, and (8.304166666666667,2.202777777777778) charging behavior.
# (2655, 15)
# working on user with 91 total_capacity, 22 rate of charge, and (7.255833333333333,2.106388888888889) charging behavior.
# (2683, 15)
# working on user with 71 total_capacity, 22 rate of charge, and (7.3502777777777775,2.207777777777778) charging behavior.
# (2711, 15)
# working on user with 84 total_capacity, 11 rate of charge, and (8.269722222222223,2.0530555555555554) charging behavior.
# (2739, 15)
# working on user with 109 total_capacity, 7.4 rate of charge, and (6.870833333333334,2.026666666666667) charging behavior.
# (2767, 15)
# working on user with 52 total_capacity, 11 rate of charge, and (6.739166666666667,2.0894444444444447) charging behavior.
# (2795, 15)
# working on user with 84 total_capacity, 22 rate of charge, and (7.236111111111111,2.102222222222222) charging behavior.
# (2823, 15)
# working on user with 67 total_capacity, 11 rate of charge, and (7.075833333333334,1.9077777777777778) charging behavior.
# (2851, 15)
# working on user with 34 total_capacity, 11 rate of charge, and (5.6466666666666665,2.0919444444444446) charging behavior.
# (2879, 15)
# working on user with 27 total_capacity, 11 rate of charge, and (8.246944444444445,2.0175) charging behavior.
# (2907, 15)
# working on user with 112 total_capacity, 7.4 rate of charge, and (5.983888888888889,2.0708333333333333) charging behavior.
# (2935, 15)
# working on user with 57 total_capacity, 22 rate of charge, and (5.627777777777778,2.0341666666666667) charging behavior.
# (2963, 15)
# working on user with 66 total_capacity, 7.4 rate of charge, and (7.4175,2.0941666666666667) charging behavior.
# (2991, 15)
# working on user with 43 total_capacity, 7.4 rate of charge, and (8.13888888888889,2.1069444444444443) charging behavior.
# (3019, 15)
# working on user with 55 total_capacity, 22 rate of charge, and (5.863611111111111,2.0508333333333333) charging behavior.
# (3047, 15)
# working on user with 64 total_capacity, 11 rate of charge, and (7.607222222222222,2.1405555555555558) charging behavior.
# (3075, 15)
# working on user with 78 total_capacity, 7.4 rate of charge, and (6.219444444444444,2.037777777777778) charging behavior.
# (3103, 15)
# working on user with 29 total_capacity, 11 rate of charge, and (6.065555555555555,1.9480555555555557) charging behavior.
# (3131, 15)
# working on user with 60 total_capacity, 22 rate of charge, and (8.25388888888889,2.152222222222222) charging behavior.
# (3159, 15)
# working on user with 117 total_capacity, 7.4 rate of charge, and (6.428333333333334,1.9319444444444445) charging behavior.
# (3187, 15)
# working on user with 22 total_capacity, 11 rate of charge, and (6.984444444444445,1.9283333333333332) charging behavior.
# (3215, 15)
# working on user with 86 total_capacity, 7.4 rate of charge, and (6.113333333333333,1.995) charging behavior.
# (3243, 15)
# working on user with 33 total_capacity, 11 rate of charge, and (6.414444444444444,2.1863888888888887) charging behavior.
# (3271, 15)
# working on user with 94 total_capacity, 22 rate of charge, and (7.420277777777778,2.1469444444444443) charging behavior.
# (3299, 15)
# working on user with 28 total_capacity, 7.4 rate of charge, and (7.27,1.9561111111111111) charging behavior.
# (3327, 15)
# working on user with 102 total_capacity, 11 rate of charge, and (6.184444444444445,2.1575) charging behavior.
# (3355, 15)
# working on user with 72 total_capacity, 11 rate of charge, and (6.941111111111111,1.9769444444444444) charging behavior.
# (3383, 15)
# working on user with 39 total_capacity, 22 rate of charge, and (5.899444444444445,1.9872222222222222) charging behavior.
# (3411, 15)
# working on user with 61 total_capacity, 7.4 rate of charge, and (7.888888888888889,2.1547222222222224) charging behavior.
# (3439, 15)
# working on user with 70 total_capacity, 11 rate of charge, and (6.861666666666666,1.9825) charging behavior.
# (3467, 15)
# working on user with 59 total_capacity, 11 rate of charge, and (7.075,1.9080555555555556) charging behavior.
# (3495, 15)
# working on user with 120 total_capacity, 22 rate of charge, and (7.536944444444444,2.1577777777777776) charging behavior.
# (3523, 15)
# working on user with 98 total_capacity, 11 rate of charge, and (6.219444444444444,2.045) charging behavior.
# (3551, 15)
# working on user with 123 total_capacity, 22 rate of charge, and (5.871666666666667,1.9211111111111112) charging behavior.
# (3579, 15)
# working on user with 33 total_capacity, 11 rate of charge, and (6.265833333333333,2.066666666666667) charging behavior.
# (3607, 15)
# working on user with 106 total_capacity, 7.4 rate of charge, and (7.606944444444444,2.0658333333333334) charging behavior.
# (3635, 15)
# working on user with 70 total_capacity, 22 rate of charge, and (5.723888888888889,2.214166666666667) charging behavior.
# (3663, 15)
# working on user with 80 total_capacity, 7.4 rate of charge, and (7.761388888888889,2.066666666666667) charging behavior.
# (3691, 15)
# working on user with 26 total_capacity, 22 rate of charge, and (7.65,1.9594444444444445) charging behavior.
# (3719, 15)
# working on user with 119 total_capacity, 22 rate of charge, and (5.646388888888889,2.154166666666667) charging behavior.
# (3747, 15)
# working on user with 71 total_capacity, 11 rate of charge, and (6.1691666666666665,2.187222222222222) charging behavior.
# (3775, 15)
# working on user with 108 total_capacity, 22 rate of charge, and (6.3261111111111115,2.045) charging behavior.
# (3803, 15)
# working on user with 25 total_capacity, 11 rate of charge, and (6.243888888888889,2.1825) charging behavior.
# (3831, 15)
# working on user with 68 total_capacity, 22 rate of charge, and (8.094444444444445,2.1508333333333334) charging behavior.
# (3859, 15)
# working on user with 54 total_capacity, 11 rate of charge, and (6.961666666666667,2.112222222222222) charging behavior.
# (3887, 15)
# working on user with 34 total_capacity, 11 rate of charge, and (7.505,2.123611111111111) charging behavior.
# (3915, 15)
# working on user with 83 total_capacity, 11 rate of charge, and (7.040555555555556,2.1238888888888887) charging behavior.
# (3943, 15)
# working on user with 114 total_capacity, 7.4 rate of charge, and (6.480555555555555,2.2025) charging behavior.
# (3971, 15)
# working on user with 41 total_capacity, 11 rate of charge, and (6.706944444444445,2.112222222222222) charging behavior.
# (3999, 15)
# working on user with 75 total_capacity, 22 rate of charge, and (5.685,1.9172222222222222) charging behavior.
# (4027, 15)
# working on user with 49 total_capacity, 7.4 rate of charge, and (6.700555555555556,2.058611111111111) charging behavior.
# (4055, 15)
# working on user with 26 total_capacity, 11 rate of charge, and (5.894166666666667,2.0275) charging behavior.
# (4083, 15)
# working on user with 117 total_capacity, 7.4 rate of charge, and (6.115555555555556,1.9947222222222223) charging behavior.
# (4111, 15)
# working on user with 39 total_capacity, 7.4 rate of charge, and (7.663055555555555,2.0166666666666666) charging behavior.
# (4139, 15)
# working on user with 47 total_capacity, 22 rate of charge, and (7.44,2.0766666666666667) charging behavior.
# (4167, 15)
# working on user with 118 total_capacity, 22 rate of charge, and (5.955,1.9452777777777779) charging behavior.
# (4195, 15)
# working on user with 21 total_capacity, 22 rate of charge, and (7.441666666666666,2.0836111111111113) charging behavior.
# (4223, 15)
# working on user with 109 total_capacity, 7.4 rate of charge, and (6.4911111111111115,2.174166666666667) charging behavior.
# (4251, 15)
# working on user with 64 total_capacity, 11 rate of charge, and (6.174722222222222,1.9513888888888888) charging behavior.
# (4279, 15)
# working on user with 25 total_capacity, 7.4 rate of charge, and (6.416944444444445,2.140833333333333) charging behavior.
# (4307, 15)
# working on user with 76 total_capacity, 7.4 rate of charge, and (8.268611111111111,1.93) charging behavior.
# (4335, 15)
# working on user with 119 total_capacity, 7.4 rate of charge, and (7.535555555555556,1.9355555555555555) charging behavior.
# (4363, 15)
# working on user with 98 total_capacity, 11 rate of charge, and (7.5777777777777775,2.2016666666666667) charging behavior.
# (4391, 15)
# working on user with 67 total_capacity, 11 rate of charge, and (7.981944444444444,2.0283333333333333) charging behavior.
# (4419, 15)
# working on user with 111 total_capacity, 11 rate of charge, and (7.799166666666666,2.104722222222222) charging behavior.
# (4447, 15)
# working on user with 38 total_capacity, 22 rate of charge, and (6.6725,2.1425) charging behavior.
# (4475, 15)
# working on user with 121 total_capacity, 7.4 rate of charge, and (7.966944444444445,2.0144444444444445) charging behavior.
# (4503, 15)
# working on user with 51 total_capacity, 11 rate of charge, and (6.220555555555555,1.9894444444444443) charging behavior.
# (4531, 15)
# working on user with 55 total_capacity, 7.4 rate of charge, and (7.006111111111111,2.2155555555555555) charging behavior.
# (4559, 15)
# working on user with 72 total_capacity, 22 rate of charge, and (7.405555555555556,2.0791666666666666) charging behavior.
# (4587, 15)
# working on user with 96 total_capacity, 22 rate of charge, and (8.0675,2.18) charging behavior.
# (4615, 15)
# working on user with 62 total_capacity, 11 rate of charge, and (7.908055555555555,2.1425) charging behavior.
# (4643, 15)
# working on user with 34 total_capacity, 11 rate of charge, and (7.397222222222222,1.9469444444444444) charging behavior.
# (4671, 15)
# working on user with 120 total_capacity, 7.4 rate of charge, and (7.8575,2.0966666666666667) charging behavior.
# (4699, 15)
# working on user with 44 total_capacity, 11 rate of charge, and (7.934722222222222,1.9508333333333334) charging behavior.
# (4727, 15)
# working on user with 62 total_capacity, 22 rate of charge, and (7.275,1.9083333333333334) charging behavior.
# (4755, 15)
# working on user with 91 total_capacity, 22 rate of charge, and (7.308611111111111,2.1838888888888888) charging behavior.
# (4783, 15)
# working on user with 35 total_capacity, 11 rate of charge, and (5.670833333333333,1.8933333333333333) charging behavior.
# (4811, 15)
# working on user with 102 total_capacity, 22 rate of charge, and (6.416666666666667,2.1552777777777776) charging behavior.
# (4839, 15)
# working on user with 51 total_capacity, 22 rate of charge, and (6.3,2.0919444444444446) charging behavior.
# (4867, 15)
# working on user with 90 total_capacity, 11 rate of charge, and (6.536388888888889,1.9713888888888889) charging behavior.
# (4895, 15)
# working on user with 55 total_capacity, 11 rate of charge, and (7.895277777777777,2.005) charging behavior.
# (4923, 15)
# working on user with 108 total_capacity, 11 rate of charge, and (6.771944444444444,2.0305555555555554) charging behavior.
# (4951, 15)
# working on user with 72 total_capacity, 7.4 rate of charge, and (7.622222222222222,2.206111111111111) charging behavior.
# (4979, 15)
# working on user with 123 total_capacity, 22 rate of charge, and (5.818333333333333,1.9477777777777778) charging behavior.
# (5006, 15)
# working on user with 21 total_capacity, 22 rate of charge, and (7.1625,1.9980555555555555) charging behavior.
# (5034, 15)
# working on user with 93 total_capacity, 22 rate of charge, and (7.121388888888889,2.0327777777777776) charging behavior.
# (5062, 15)
# working on user with 98 total_capacity, 22 rate of charge, and (6.925833333333333,2.046666666666667) charging behavior.
# (5090, 15)
# working on user with 46 total_capacity, 11 rate of charge, and (6.354722222222223,2.1041666666666665) charging behavior.
# (5118, 15)
# working on user with 89 total_capacity, 22 rate of charge, and (5.862777777777778,2.1275) charging behavior.
# (5146, 15)
# working on user with 94 total_capacity, 22 rate of charge, and (8.0125,2.202777777777778) charging behavior.
# (5174, 15)
# working on user with 40 total_capacity, 11 rate of charge, and (8.01,2.194722222222222) charging behavior.
# (5202, 15)
# working on user with 71 total_capacity, 7.4 rate of charge, and (7.795,2.151388888888889) charging behavior.
# (5230, 15)
# working on user with 117 total_capacity, 22 rate of charge, and (6.442222222222222,2.106388888888889) charging behavior.
# (5258, 15)
# working on user with 26 total_capacity, 7.4 rate of charge, and (5.5938888888888885,2.2108333333333334) charging behavior.
# (5286, 15)
# working on user with 31 total_capacity, 22 rate of charge, and (6.238333333333333,2.062777777777778) charging behavior.
# (5314, 15)
# working on user with 75 total_capacity, 11 rate of charge, and (6.4425,1.8991666666666667) charging behavior.
# (5342, 15)
# working on user with 56 total_capacity, 7.4 rate of charge, and (6.185555555555555,2.078333333333333) charging behavior.
# (5370, 15)
# working on user with 101 total_capacity, 11 rate of charge, and (6.038611111111111,2.2044444444444444) charging behavior.
# (5398, 15)
# working on user with 48 total_capacity, 7.4 rate of charge, and (7.729166666666667,2.101111111111111) charging behavior.
# (5426, 15)
# working on user with 42 total_capacity, 11 rate of charge, and (7.974444444444444,2.1133333333333333) charging behavior.
# (5454, 15)
# working on user with 49 total_capacity, 7.4 rate of charge, and (7.214166666666666,2.09) charging behavior.
# (5482, 15)
# working on user with 35 total_capacity, 22 rate of charge, and (7.678888888888889,2.1977777777777776) charging behavior.
# (5510, 15)
# working on user with 29 total_capacity, 7.4 rate of charge, and (7.870555555555556,1.9047222222222222) charging behavior.
# (5538, 15)
# working on user with 29 total_capacity, 7.4 rate of charge, and (7.5055555555555555,2.180833333333333) charging behavior.
# (5566, 15)
# working on user with 121 total_capacity, 11 rate of charge, and (5.733055555555556,2.158888888888889) charging behavior.
# (5594, 15)
# working on user with 108 total_capacity, 22 rate of charge, and (6.2625,2.129166666666667) charging behavior.
# (5622, 15)
# working on user with 40 total_capacity, 11 rate of charge, and (7.094722222222222,2.1036111111111113) charging behavior.
# (5650, 15)
# working on user with 59 total_capacity, 11 rate of charge, and (6.253888888888889,2.1894444444444443) charging behavior.
# (5678, 15)
# working on user with 111 total_capacity, 7.4 rate of charge, and (7.714444444444444,2.1594444444444445) charging behavior.
# (5706, 15)
# working on user with 36 total_capacity, 11 rate of charge, and (6.799444444444444,2.1358333333333333) charging behavior.
# (5734, 15)
# working on user with 79 total_capacity, 11 rate of charge, and (7.849722222222222,1.941111111111111) charging behavior.
# (5762, 15)
# working on user with 54 total_capacity, 11 rate of charge, and (7.733055555555556,2.214166666666667) charging behavior.
# (5790, 15)
# working on user with 48 total_capacity, 22 rate of charge, and (5.588333333333333,2.2083333333333335) charging behavior.
# (5817, 15)
# working on user with 37 total_capacity, 22 rate of charge, and (7.024166666666667,2.056111111111111) charging behavior.
# (5845, 15)
# working on user with 61 total_capacity, 7.4 rate of charge, and (7.224166666666667,2.1366666666666667) charging behavior.
# (5873, 15)
# working on user with 116 total_capacity, 7.4 rate of charge, and (6.384166666666666,2.125277777777778) charging behavior.
# (5901, 15)
# working on user with 76 total_capacity, 22 rate of charge, and (5.868333333333333,2.0455555555555556) charging behavior.
# (5929, 15)
# working on user with 49 total_capacity, 11 rate of charge, and (6.731388888888889,1.9552777777777777) charging behavior.
# (5957, 15)
# working on user with 76 total_capacity, 11 rate of charge, and (7.075833333333334,1.9230555555555555) charging behavior.
# (5985, 15)
# working on user with 40 total_capacity, 11 rate of charge, and (5.701944444444444,2.133611111111111) charging behavior.
# (6013, 15)
# working on user with 24 total_capacity, 11 rate of charge, and (7.170555555555556,2.2169444444444446) charging behavior.
# (6041, 15)
# working on user with 30 total_capacity, 22 rate of charge, and (5.691666666666666,1.9525) charging behavior.
# (6069, 15)
# working on user with 85 total_capacity, 7.4 rate of charge, and (7.049444444444444,1.9761111111111112) charging behavior.
# (6096, 15)
# working on user with 82 total_capacity, 11 rate of charge, and (7.638055555555556,2.015277777777778) charging behavior.
# (6124, 15)
# working on user with 41 total_capacity, 22 rate of charge, and (8.073055555555555,2.1866666666666665) charging behavior.
# (6152, 15)
# working on user with 73 total_capacity, 7.4 rate of charge, and (6.821666666666666,2.0722222222222224) charging behavior.
# (6180, 15)
# working on user with 88 total_capacity, 7.4 rate of charge, and (5.809444444444445,2.080277777777778) charging behavior.
# (6208, 15)
# working on user with 96 total_capacity, 7.4 rate of charge, and (6.373611111111111,2.1730555555555555) charging behavior.
# (6236, 15)
# working on user with 64 total_capacity, 22 rate of charge, and (5.792222222222223,2.1502777777777777) charging behavior.
# (6264, 15)
# working on user with 38 total_capacity, 22 rate of charge, and (7.351111111111111,2.0861111111111112) charging behavior.
# (6292, 15)
# working on user with 45 total_capacity, 22 rate of charge, and (6.075555555555556,2.066388888888889) charging behavior.
# (6320, 15)
# working on user with 23 total_capacity, 22 rate of charge, and (8.181944444444444,1.9147222222222222) charging behavior.
# (6348, 15)
# working on user with 83 total_capacity, 22 rate of charge, and (7.283333333333333,2.0955555555555554) charging behavior.
# (6376, 15)
# working on user with 65 total_capacity, 11 rate of charge, and (6.0311111111111115,2.0944444444444446) charging behavior.
# (6404, 15)
# working on user with 85 total_capacity, 7.4 rate of charge, and (7.423611111111111,1.918611111111111) charging behavior.
# (6432, 15)
# working on user with 59 total_capacity, 7.4 rate of charge, and (5.621666666666667,1.923888888888889) charging behavior.
# (6460, 15)
# working on user with 114 total_capacity, 7.4 rate of charge, and (6.441388888888889,1.9675) charging behavior.
# (6488, 15)
# working on user with 113 total_capacity, 22 rate of charge, and (6.2716666666666665,2.1466666666666665) charging behavior.
# (6516, 15)
# working on user with 115 total_capacity, 7.4 rate of charge, and (7.685833333333333,2.101111111111111) charging behavior.
# (6544, 15)
# working on user with 25 total_capacity, 7.4 rate of charge, and (6.510277777777778,2.102222222222222) charging behavior.
# (6572, 15)
# working on user with 116 total_capacity, 7.4 rate of charge, and (6.783611111111111,1.9288888888888889) charging behavior.
# (6600, 15)
# working on user with 34 total_capacity, 11 rate of charge, and (6.663055555555555,2.1891666666666665) charging behavior.
# (6628, 15)
# working on user with 69 total_capacity, 22 rate of charge, and (5.845,1.9880555555555555) charging behavior.
# (6656, 15)
# working on user with 111 total_capacity, 11 rate of charge, and (7.5872222222222225,2.026666666666667) charging behavior.
# (6684, 15)
# working on user with 32 total_capacity, 11 rate of charge, and (7.325,2.0172222222222222) charging behavior.
# (6712, 15)
# working on user with 91 total_capacity, 11 rate of charge, and (7.612222222222222,2.051388888888889) charging behavior.
# (6740, 15)
# working on user with 102 total_capacity, 7.4 rate of charge, and (6.594444444444444,1.8922222222222222) charging behavior.
# (6768, 15)
# working on user with 122 total_capacity, 11 rate of charge, and (6.976388888888889,1.9288888888888889) charging behavior.
# (6796, 15)
# working on user with 47 total_capacity, 7.4 rate of charge, and (6.320277777777778,2.1466666666666665) charging behavior.
# (6824, 15)
# working on user with 107 total_capacity, 7.4 rate of charge, and (6.567222222222222,1.896388888888889) charging behavior.
# (6852, 15)
# working on user with 79 total_capacity, 11 rate of charge, and (7.171666666666667,2.118611111111111) charging behavior.
# (6880, 15)
# working on user with 93 total_capacity, 22 rate of charge, and (6.260277777777778,2.0572222222222223) charging behavior.
# (6908, 15)
# working on user with 58 total_capacity, 7.4 rate of charge, and (8.05638888888889,1.8905555555555555) charging behavior.
# (6936, 15)
# working on user with 59 total_capacity, 11 rate of charge, and (7.2652777777777775,2.056388888888889) charging behavior.
# (6964, 15)
# working on user with 89 total_capacity, 22 rate of charge, and (6.873333333333333,2.1869444444444444) charging behavior.
# (6992, 15)
# working on user with 60 total_capacity, 22 rate of charge, and (7.680833333333333,2.0816666666666666) charging behavior.
# (7020, 15)
# working on user with 29 total_capacity, 7.4 rate of charge, and (7.698888888888889,2.0297222222222224) charging behavior.
# (7048, 15)
# working on user with 67 total_capacity, 11 rate of charge, and (8.188333333333333,1.9130555555555555) charging behavior.
# (7076, 15)
# working on user with 36 total_capacity, 11 rate of charge, and (6.5969444444444445,1.9230555555555555) charging behavior.
# (7104, 15)
# working on user with 84 total_capacity, 7.4 rate of charge, and (8.285555555555556,2.042222222222222) charging behavior.
# (7132, 15)
# working on user with 109 total_capacity, 7.4 rate of charge, and (7.301944444444445,1.896111111111111) charging behavior.
# (7160, 15)
# working on user with 93 total_capacity, 22 rate of charge, and (6.344722222222222,2.1455555555555557) charging behavior.
# (7188, 15)
# working on user with 103 total_capacity, 22 rate of charge, and (8.057777777777778,2.1675) charging behavior.
# (7216, 15)
# working on user with 94 total_capacity, 11 rate of charge, and (5.871388888888889,2.178888888888889) charging behavior.
# (7244, 15)
# working on user with 80 total_capacity, 7.4 rate of charge, and (6.98,2.1475) charging behavior.
# (7272, 15)
# working on user with 84 total_capacity, 11 rate of charge, and (7.7347222222222225,2.1533333333333333) charging behavior.
# (7300, 15)
# working on user with 65 total_capacity, 11 rate of charge, and (8.207222222222223,2.07) charging behavior.
# (7328, 15)
# working on user with 100 total_capacity, 11 rate of charge, and (6.068611111111111,2.2069444444444444) charging behavior.
# (7356, 15)
# working on user with 118 total_capacity, 7.4 rate of charge, and (6.978611111111111,1.9308333333333334) charging behavior.
# (7384, 15)
# working on user with 50 total_capacity, 22 rate of charge, and (5.659722222222222,2.205277777777778) charging behavior.
# (7412, 15)
# working on user with 42 total_capacity, 11 rate of charge, and (7.478055555555556,1.9388888888888889) charging behavior.
# (7440, 15)
# working on user with 111 total_capacity, 11 rate of charge, and (6.865833333333334,2.2219444444444445) charging behavior.
# (7468, 15)
# working on user with 116 total_capacity, 7.4 rate of charge, and (8.055277777777778,2.0105555555555554) charging behavior.
# (7496, 15)
# working on user with 64 total_capacity, 11 rate of charge, and (6.593333333333334,1.9594444444444445) charging behavior.
# (7524, 15)
# working on user with 121 total_capacity, 11 rate of charge, and (7.7186111111111115,2.220833333333333) charging behavior.
# (7552, 15)
# working on user with 50 total_capacity, 22 rate of charge, and (8.275,1.9425) charging behavior.
# (7580, 15)
# working on user with 57 total_capacity, 7.4 rate of charge, and (5.9225,2.0433333333333334) charging behavior.
# (7608, 15)
# working on user with 90 total_capacity, 7.4 rate of charge, and (5.614444444444445,2.033888888888889) charging behavior.
# (7636, 15)
# working on user with 47 total_capacity, 11 rate of charge, and (7.280555555555556,1.9569444444444444) charging behavior.
# (7664, 15)
# working on user with 62 total_capacity, 11 rate of charge, and (6.4525,2.182777777777778) charging behavior.
# (7692, 15)
# working on user with 53 total_capacity, 11 rate of charge, and (5.598333333333334,1.9047222222222222) charging behavior.
# (7720, 15)
# working on user with 103 total_capacity, 7.4 rate of charge, and (7.1338888888888885,2.111666666666667) charging behavior.
# (7747, 15)
# working on user with 61 total_capacity, 22 rate of charge, and (7.7683333333333335,1.9958333333333333) charging behavior.
# (7775, 15)
# working on user with 96 total_capacity, 22 rate of charge, and (5.591666666666667,2.160277777777778) charging behavior.
# (7801, 15)
# working on user with 116 total_capacity, 22 rate of charge, and (7.598888888888889,1.9908333333333332) charging behavior.
# (7829, 15)
# working on user with 23 total_capacity, 22 rate of charge, and (6.626944444444445,2.2025) charging behavior.
# (7857, 15)
# working on user with 49 total_capacity, 22 rate of charge, and (7.8741666666666665,2.0669444444444443) charging behavior.
# (7885, 15)
# working on user with 67 total_capacity, 11 rate of charge, and (7.585833333333333,1.9858333333333333) charging behavior.
# (7913, 15)
# working on user with 35 total_capacity, 11 rate of charge, and (8.277777777777779,1.9922222222222221) charging behavior.
# (7941, 15)
# working on user with 60 total_capacity, 22 rate of charge, and (8.179444444444444,2.2041666666666666) charging behavior.
# (7969, 15)
# working on user with 83 total_capacity, 11 rate of charge, and (7.8822222222222225,2.176388888888889) charging behavior.
# (7997, 15)
# working on user with 33 total_capacity, 11 rate of charge, and (6.096666666666667,1.9222222222222223) charging behavior.
# (8025, 15)
# working on user with 57 total_capacity, 22 rate of charge, and (7.152222222222222,2.018611111111111) charging behavior.
# (8053, 15)
# working on user with 31 total_capacity, 11 rate of charge, and (6.041388888888889,1.8991666666666667) charging behavior.
# (8081, 15)
# working on user with 32 total_capacity, 7.4 rate of charge, and (8.098888888888888,1.9722222222222223) charging behavior.
# (8109, 15)
# working on user with 66 total_capacity, 22 rate of charge, and (5.713333333333333,1.9708333333333334) charging behavior.
# (8136, 15)
# working on user with 64 total_capacity, 22 rate of charge, and (8.054722222222223,1.958611111111111) charging behavior.
# (8164, 15)
# working on user with 76 total_capacity, 7.4 rate of charge, and (7.374444444444444,2.1777777777777776) charging behavior.
# (8192, 15)
# working on user with 107 total_capacity, 7.4 rate of charge, and (5.591666666666667,2.091111111111111) charging behavior.
# (8220, 15)
# working on user with 34 total_capacity, 7.4 rate of charge, and (8.0875,2.183333333333333) charging behavior.
# (8248, 15)
# working on user with 31 total_capacity, 22 rate of charge, and (6.357222222222222,2.0275) charging behavior.
# (8276, 15)
# working on user with 97 total_capacity, 22 rate of charge, and (8.291666666666666,1.8911111111111112) charging behavior.
# (8304, 15)
# working on user with 102 total_capacity, 22 rate of charge, and (7.92,2.2127777777777777) charging behavior.
# (8332, 15)
# working on user with 50 total_capacity, 22 rate of charge, and (8.279166666666667,1.9513888888888888) charging behavior.
# (8360, 15)
# working on user with 108 total_capacity, 11 rate of charge, and (6.746944444444445,1.9880555555555555) charging behavior.
# (8388, 15)
# working on user with 86 total_capacity, 7.4 rate of charge, and (7.708888888888889,1.9047222222222222) charging behavior.
# (8416, 15)
# working on user with 49 total_capacity, 11 rate of charge, and (6.274166666666667,2.213611111111111) charging behavior.
# (8444, 15)
# working on user with 80 total_capacity, 11 rate of charge, and (7.395833333333333,1.94) charging behavior.
# (8472, 15)
# working on user with 106 total_capacity, 11 rate of charge, and (7.222222222222222,1.9805555555555556) charging behavior.
# (8500, 15)
# working on user with 96 total_capacity, 22 rate of charge, and (5.680833333333333,2.1694444444444443) charging behavior.
# (8528, 15)
# working on user with 67 total_capacity, 11 rate of charge, and (5.922777777777778,1.96) charging behavior.
# (8556, 15)
# working on user with 113 total_capacity, 22 rate of charge, and (6.846111111111111,2.004166666666667) charging behavior.
# (8584, 15)
# working on user with 112 total_capacity, 7.4 rate of charge, and (6.212777777777778,2.1633333333333336) charging behavior.
# (8612, 15)
# working on user with 40 total_capacity, 11 rate of charge, and (7.144166666666667,2.1530555555555555) charging behavior.
# (8640, 15)
# working on user with 32 total_capacity, 22 rate of charge, and (6.053055555555556,2.1244444444444444) charging behavior.
# (8668, 15)
# working on user with 98 total_capacity, 11 rate of charge, and (5.751111111111111,1.9594444444444445) charging behavior.
# (8696, 15)
# working on user with 103 total_capacity, 11 rate of charge, and (7.659722222222222,1.9544444444444444) charging behavior.
# (8724, 15)
# working on user with 119 total_capacity, 11 rate of charge, and (5.810277777777777,1.8908333333333334) charging behavior.
# (8752, 15)
# working on user with 65 total_capacity, 7.4 rate of charge, and (5.830555555555556,2.192222222222222) charging behavior.
# (8780, 15)
# working on user with 104 total_capacity, 22 rate of charge, and (6.482777777777778,1.9413888888888888) charging behavior.
# (8808, 15)
# working on user with 31 total_capacity, 11 rate of charge, and (7.307222222222222,2.0966666666666667) charging behavior.
# (8836, 15)
# working on user with 65 total_capacity, 11 rate of charge, and (6.7380555555555555,2.036111111111111) charging behavior.
# (8864, 15)
# working on user with 22 total_capacity, 11 rate of charge, and (7.903888888888889,1.9383333333333332) charging behavior.
# (8892, 15)
# working on user with 75 total_capacity, 7.4 rate of charge, and (7.0,2.0258333333333334) charging behavior.
# (8920, 15)
# working on user with 104 total_capacity, 7.4 rate of charge, and (8.178611111111111,2.1430555555555557) charging behavior.
# (8948, 15)
# working on user with 66 total_capacity, 7.4 rate of charge, and (7.425833333333333,1.975) charging behavior.
# (8976, 15)
# working on user with 108 total_capacity, 7.4 rate of charge, and (6.458055555555555,2.02) charging behavior.
# (9004, 15)
# working on user with 105 total_capacity, 7.4 rate of charge, and (6.594444444444444,2.127222222222222) charging behavior.
# (9032, 15)
# working on user with 42 total_capacity, 7.4 rate of charge, and (8.078055555555556,2.152222222222222) charging behavior.
# (9060, 15)
# working on user with 62 total_capacity, 22 rate of charge, and (8.298055555555555,2.0294444444444446) charging behavior.
# (9088, 15)
# working on user with 43 total_capacity, 11 rate of charge, and (5.6658333333333335,1.9125) charging behavior.
# (9116, 15)
# working on user with 101 total_capacity, 7.4 rate of charge, and (6.861944444444444,1.9408333333333334) charging behavior.
# (9144, 15)
# working on user with 92 total_capacity, 11 rate of charge, and (7.724444444444444,1.9388888888888889) charging behavior.
# (9172, 15)
# working on user with 74 total_capacity, 22 rate of charge, and (7.115555555555556,2.0216666666666665) charging behavior.
# (9200, 15)
# working on user with 104 total_capacity, 11 rate of charge, and (7.163055555555555,1.9905555555555556) charging behavior.
# (9228, 15)
# working on user with 114 total_capacity, 22 rate of charge, and (7.296666666666667,2.1597222222222223) charging behavior.
# (9255, 15)
# working on user with 93 total_capacity, 22 rate of charge, and (5.870555555555556,1.8936111111111111) charging behavior.
# (9283, 15)
# working on user with 111 total_capacity, 7.4 rate of charge, and (7.121666666666667,2.1308333333333334) charging behavior.
# (9311, 15)
# working on user with 38 total_capacity, 22 rate of charge, and (7.898333333333333,2.0794444444444444) charging behavior.
# (9339, 15)
# working on user with 51 total_capacity, 11 rate of charge, and (7.7875,1.9091666666666667) charging behavior.
# (9367, 15)
# working on user with 67 total_capacity, 11 rate of charge, and (8.14611111111111,2.058333333333333) charging behavior.
# (9395, 15)
# working on user with 30 total_capacity, 7.4 rate of charge, and (6.202222222222222,2.0375) charging behavior.
# (9423, 15)
# working on user with 123 total_capacity, 22 rate of charge, and (7.525277777777778,2.015277777777778) charging behavior.
# (9451, 15)
# working on user with 122 total_capacity, 11 rate of charge, and (5.780833333333334,1.958888888888889) charging behavior.
# (9479, 15)
# working on user with 76 total_capacity, 22 rate of charge, and (7.645,2.0975) charging behavior.
# (9507, 15)
# working on user with 53 total_capacity, 11 rate of charge, and (6.676111111111111,2.044722222222222) charging behavior.
# (9535, 15)
# working on user with 108 total_capacity, 7.4 rate of charge, and (6.211666666666667,2.2194444444444446) charging behavior.
# (9563, 15)
# working on user with 88 total_capacity, 22 rate of charge, and (7.550277777777778,2.1905555555555556) charging behavior.
# (9591, 15)
# working on user with 115 total_capacity, 22 rate of charge, and (5.842777777777778,2.17) charging behavior.
# (9619, 15)
# working on user with 70 total_capacity, 11 rate of charge, and (6.461944444444445,2.1369444444444445) charging behavior.
# (9647, 15)
# working on user with 109 total_capacity, 7.4 rate of charge, and (7.711666666666667,2.1463888888888887) charging behavior.
# (9675, 15)
# working on user with 60 total_capacity, 22 rate of charge, and (8.252777777777778,2.1416666666666666) charging behavior.
# (9703, 15)
# working on user with 41 total_capacity, 11 rate of charge, and (6.896111111111111,1.99) charging behavior.
# (9731, 15)
# working on user with 83 total_capacity, 11 rate of charge, and (7.4425,1.9152777777777779) charging behavior.
# (9759, 15)
# working on user with 91 total_capacity, 11 rate of charge, and (7.828333333333333,2.0566666666666666) charging behavior.
# (9787, 15)
# working on user with 30 total_capacity, 11 rate of charge, and (8.261388888888888,2.125277777777778) charging behavior.
# (9815, 15)
# working on user with 76 total_capacity, 7.4 rate of charge, and (5.777222222222222,2.105) charging behavior.
# (9843, 15)
# working on user with 66 total_capacity, 7.4 rate of charge, and (7.430555555555555,2.202777777777778) charging behavior.
# (9871, 15)
# working on user with 121 total_capacity, 7.4 rate of charge, and (5.755833333333333,2.101111111111111) charging behavior.
# (9899, 15)
# working on user with 105 total_capacity, 7.4 rate of charge, and (7.256111111111111,1.8980555555555556) charging behavior.
# (9927, 15)
# working on user with 78 total_capacity, 22 rate of charge, and (6.377777777777778,1.98) charging behavior.
# (9955, 15)
# working on user with 59 total_capacity, 22 rate of charge, and (7.986111111111111,2.203611111111111) charging behavior.
# (9983, 15)
# working on user with 108 total_capacity, 22 rate of charge, and (6.856944444444444,2.0183333333333335) charging behavior.
# (10011, 15)
# working on user with 73 total_capacity, 11 rate of charge, and (8.292777777777777,2.200277777777778) charging behavior.
# (10039, 15)
# working on user with 93 total_capacity, 11 rate of charge, and (5.849444444444444,2.089166666666667) charging behavior.
# (10067, 15)
# working on user with 118 total_capacity, 11 rate of charge, and (7.970555555555555,1.8941666666666668) charging behavior.
# (10095, 15)
# working on user with 56 total_capacity, 22 rate of charge, and (6.745833333333334,1.9213888888888888) charging behavior.
# (10123, 15)
# working on user with 60 total_capacity, 11 rate of charge, and (8.240833333333333,1.9202777777777778) charging behavior.
# (10151, 15)
# working on user with 43 total_capacity, 7.4 rate of charge, and (7.944166666666667,2.1197222222222223) charging behavior.
# (10179, 15)
# working on user with 36 total_capacity, 22 rate of charge, and (7.455277777777778,1.9266666666666667) charging behavior.
# (10207, 15)
# working on user with 80 total_capacity, 7.4 rate of charge, and (6.664444444444444,2.212222222222222) charging behavior.
# (10235, 15)
# working on user with 23 total_capacity, 11 rate of charge, and (6.384722222222222,2.153611111111111) charging behavior.
# (10263, 15)
# working on user with 29 total_capacity, 11 rate of charge, and (6.374722222222222,2.185277777777778) charging behavior.
# (10291, 15)
# working on user with 88 total_capacity, 22 rate of charge, and (6.5325,1.9127777777777777) charging behavior.
# (10319, 15)
# working on user with 27 total_capacity, 7.4 rate of charge, and (6.849166666666667,2.037777777777778) charging behavior.
# (10347, 15)
# ...
# working on user with 68 total_capacity, 7.4 rate of charge, and (6.783888888888889,2.0527777777777776) charging behavior.
# (24557, 15)
# working on user with 97 total_capacity, 22 rate of charge, and (7.605277777777777,2.055833333333333) charging behavior.
# (24585, 15)
# working on user with 31 total_capacity, 7.4 rate of charge, and (7.92,2.154166666666667) charging behavior.
# (24613, 15)
# working on user with 91 total_capacity, 7.4 rate of charge, and (5.842222222222222,2.1622222222222223) charging behavior.
# (24641, 15)
# working on user with 101 total_capacity, 11 rate of charge, and (7.378611111111111,2.0277777777777777) charging behavior.
# (24669, 15)
# working on user with 37 total_capacity, 7.4 rate of charge, and (5.595833333333333,2.0875) charging behavior.
# (24697, 15)
# working on user with 76 total_capacity, 11 rate of charge, and (7.965833333333333,1.9108333333333334) charging behavior.
# (24725, 15)
# working on user with 80 total_capacity, 11 rate of charge, and (6.903888888888889,2.1530555555555555) charging behavior.
# (24753, 15)
# working on user with 113 total_capacity, 7.4 rate of charge, and (7.589444444444444,2.196388888888889) charging behavior.
# (24781, 15)
# working on user with 110 total_capacity, 22 rate of charge, and (5.801666666666667,2.0930555555555554) charging behavior.
# (24809, 15)
# working on user with 62 total_capacity, 11 rate of charge, and (6.747222222222222,2.12) charging behavior.
# (24837, 15)
# working on user with 66 total_capacity, 7.4 rate of charge, and (8.182222222222222,2.1883333333333335) charging behavior.
# (24865, 15)
# working on user with 65 total_capacity, 11 rate of charge, and (5.760555555555555,2.2047222222222222) charging behavior.
# (24893, 15)
# working on user with 103 total_capacity, 22 rate of charge, and (6.661666666666667,1.978888888888889) charging behavior.
# (24921, 15)
# working on user with 30 total_capacity, 22 rate of charge, and (5.6338888888888885,2.0894444444444447) charging behavior.
# (24949, 15)
# working on user with 76 total_capacity, 7.4 rate of charge, and (7.750555555555556,2.0661111111111112) charging behavior.
# (24977, 15)
# working on user with 83 total_capacity, 22 rate of charge, and (7.576944444444444,2.0119444444444445) charging behavior.
# (25005, 15)
# working on user with 118 total_capacity, 7.4 rate of charge, and (6.851666666666667,1.9925) charging behavior.
# (25033, 15)
# working on user with 59 total_capacity, 22 rate of charge, and (6.259444444444444,1.923888888888889) charging behavior.
# (25061, 15)
# working on user with 113 total_capacity, 7.4 rate of charge, and (7.594722222222222,2.0894444444444447) charging behavior.
# (25089, 15)
# working on user with 35 total_capacity, 22 rate of charge, and (6.229722222222223,2.096111111111111) charging behavior.
# (25117, 15)
# working on user with 78 total_capacity, 22 rate of charge, and (5.924166666666666,2.1822222222222223) charging behavior.
# (25145, 15)
# working on user with 68 total_capacity, 22 rate of charge, and (6.293888888888889,2.215) charging behavior.
# (25173, 15)
# working on user with 52 total_capacity, 7.4 rate of charge, and (8.138055555555555,2.1622222222222223) charging behavior.
# (25201, 15)
# working on user with 97 total_capacity, 7.4 rate of charge, and (7.752222222222223,2.181388888888889) charging behavior.
# (25229, 15)
# working on user with 71 total_capacity, 7.4 rate of charge, and (8.12861111111111,2.109722222222222) charging behavior.
# (25257, 15)
# working on user with 25 total_capacity, 11 rate of charge, and (7.5725,2.0052777777777777) charging behavior.
# (25285, 15)
# working on user with 23 total_capacity, 11 rate of charge, and (7.111944444444444,2.186111111111111) charging behavior.
# (25313, 15)
# working on user with 101 total_capacity, 11 rate of charge, and (7.69,1.9872222222222222) charging behavior.
# (25341, 15)
# working on user with 45 total_capacity, 11 rate of charge, and (6.675,2.023888888888889) charging behavior.
# (25369, 15)
# working on user with 80 total_capacity, 11 rate of charge, and (8.3175,2.026111111111111) charging behavior.
# (25397, 15)
# working on user with 38 total_capacity, 22 rate of charge, and (6.204722222222222,2.135) charging behavior.
# (25425, 15)
# working on user with 33 total_capacity, 11 rate of charge, and (7.320277777777778,2.151388888888889) charging behavior.
# (25453, 15)
# working on user with 93 total_capacity, 7.4 rate of charge, and (8.248333333333333,2.1530555555555555) charging behavior.
# (25481, 15)
# working on user with 54 total_capacity, 22 rate of charge, and (5.673333333333333,2.1805555555555554) charging behavior.
# (25509, 15)
# working on user with 83 total_capacity, 7.4 rate of charge, and (7.748055555555555,2.118333333333333) charging behavior.
# (25537, 15)
# working on user with 98 total_capacity, 22 rate of charge, and (6.000277777777778,1.8975) charging behavior.
# (25565, 15)
# working on user with 50 total_capacity, 11 rate of charge, and (6.520555555555555,2.05) charging behavior.
# (25593, 15)
# working on user with 87 total_capacity, 22 rate of charge, and (7.2375,2.0702777777777777) charging behavior.
# (25621, 15)
# working on user with 44 total_capacity, 7.4 rate of charge, and (7.718055555555556,2.131388888888889) charging behavior.
# (25649, 15)
# working on user with 40 total_capacity, 7.4 rate of charge, and (6.696111111111111,2.093888888888889) charging behavior.
# (25677, 15)
# working on user with 70 total_capacity, 7.4 rate of charge, and (6.336388888888889,2.200277777777778) charging behavior.
# (25705, 15)
# working on user with 26 total_capacity, 11 rate of charge, and (7.663333333333333,2.1441666666666666) charging behavior.
# (25733, 15)
# working on user with 33 total_capacity, 11 rate of charge, and (6.826944444444444,2.2105555555555556) charging behavior.
# (25761, 15)
# working on user with 61 total_capacity, 11 rate of charge, and (6.819444444444445,2.1944444444444446) charging behavior.
# (25789, 15)
# working on user with 85 total_capacity, 7.4 rate of charge, and (6.093055555555556,2.173611111111111) charging behavior.
# (25817, 15)
# working on user with 77 total_capacity, 11 rate of charge, and (7.448611111111111,1.9766666666666666) charging behavior.
# (25845, 15)
# working on user with 27 total_capacity, 22 rate of charge, and (7.284166666666667,1.918611111111111) charging behavior.
# (25873, 15)
# working on user with 99 total_capacity, 11 rate of charge, and (6.103888888888889,2.1702777777777778) charging behavior.
# (25901, 15)
# working on user with 76 total_capacity, 11 rate of charge, and (7.668888888888889,2.0380555555555557) charging behavior.
# (25929, 15)
# working on user with 72 total_capacity, 22 rate of charge, and (7.584722222222222,1.9547222222222222) charging behavior.
# (25957, 15)
# working on user with 24 total_capacity, 22 rate of charge, and (6.738333333333333,2.1066666666666665) charging behavior.
# (25985, 15)
# working on user with 76 total_capacity, 11 rate of charge, and (6.466111111111111,2.0483333333333333) charging behavior.
# (26013, 15)
# working on user with 76 total_capacity, 7.4 rate of charge, and (8.002777777777778,1.966388888888889) charging behavior.
# (26041, 15)
# working on user with 107 total_capacity, 22 rate of charge, and (7.566666666666666,1.8972222222222221) charging behavior.
# (26069, 15)
# working on user with 27 total_capacity, 22 rate of charge, and (5.704722222222222,2.1169444444444445) charging behavior.
# (26097, 15)
# working on user with 91 total_capacity, 22 rate of charge, and (7.2625,2.0669444444444443) charging behavior.
# (26125, 15)
# working on user with 63 total_capacity, 11 rate of charge, and (6.814444444444445,2.1075) charging behavior.
# (26153, 15)
# working on user with 62 total_capacity, 22 rate of charge, and (7.173611111111111,2.0908333333333333) charging behavior.
# (26181, 15)
# working on user with 73 total_capacity, 7.4 rate of charge, and (6.8630555555555555,1.9641666666666666) charging behavior.
# (26209, 15)
# working on user with 110 total_capacity, 22 rate of charge, and (7.486944444444444,2.098611111111111) charging behavior.
# (26237, 15)
# working on user with 49 total_capacity, 11 rate of charge, and (8.072222222222223,2.0652777777777778) charging behavior.
# (26265, 15)
# working on user with 54 total_capacity, 22 rate of charge, and (5.854444444444445,2.1630555555555557) charging behavior.
# (26293, 15)
# working on user with 28 total_capacity, 7.4 rate of charge, and (6.351666666666667,2.008611111111111) charging behavior.
# (26321, 15)
# working on user with 27 total_capacity, 7.4 rate of charge, and (6.786111111111111,1.9508333333333334) charging behavior.
# (26349, 15)
# working on user with 81 total_capacity, 7.4 rate of charge, and (7.612777777777778,2.0791666666666666) charging behavior.
# (26377, 15)
# working on user with 37 total_capacity, 7.4 rate of charge, and (8.281944444444445,2.2091666666666665) charging behavior.
# (26405, 15)
# working on user with 76 total_capacity, 22 rate of charge, and (7.062222222222222,1.9094444444444445) charging behavior.
# (26433, 15)
# working on user with 114 total_capacity, 7.4 rate of charge, and (5.965,1.9913888888888889) charging behavior.
# (26461, 15)
# working on user with 99 total_capacity, 11 rate of charge, and (7.6177777777777775,2.116388888888889) charging behavior.
# (26489, 15)
# working on user with 118 total_capacity, 11 rate of charge, and (6.059722222222222,1.9111111111111112) charging behavior.
# (26517, 15)
# working on user with 86 total_capacity, 7.4 rate of charge, and (7.076388888888889,2.1905555555555556) charging behavior.
# (26545, 15)
# working on user with 26 total_capacity, 7.4 rate of charge, and (7.156666666666666,2.027222222222222) charging behavior.
# (26573, 15)
# working on user with 53 total_capacity, 22 rate of charge, and (6.653333333333333,1.9752777777777777) charging behavior.
# (26601, 15)
# working on user with 37 total_capacity, 11 rate of charge, and (7.074166666666667,1.903888888888889) charging behavior.
# (26629, 15)
# working on user with 100 total_capacity, 7.4 rate of charge, and (6.370277777777778,2.071388888888889) charging behavior.
# (26657, 15)
# working on user with 58 total_capacity, 11 rate of charge, and (6.096388888888889,1.8911111111111112) charging behavior.
# (26685, 15)
# working on user with 88 total_capacity, 22 rate of charge, and (7.5936111111111115,2.1863888888888887) charging behavior.
# (26713, 15)
# working on user with 66 total_capacity, 11 rate of charge, and (7.22,2.1883333333333335) charging behavior.
# (26741, 15)
# working on user with 111 total_capacity, 22 rate of charge, and (6.758055555555556,2.0083333333333333) charging behavior.
# (26769, 15)
# working on user with 97 total_capacity, 7.4 rate of charge, and (7.113611111111111,2.0380555555555557) charging behavior.
# (26797, 15)
# working on user with 72 total_capacity, 7.4 rate of charge, and (6.496666666666667,2.07) charging behavior.
# (26825, 15)
# working on user with 54 total_capacity, 22 rate of charge, and (6.420277777777778,1.8925) charging behavior.
# (26853, 15)
# working on user with 92 total_capacity, 11 rate of charge, and (5.888333333333334,2.0922222222222224) charging behavior.
# (26881, 15)
# working on user with 36 total_capacity, 22 rate of charge, and (6.8125,1.92) charging behavior.
# (26909, 15)
# working on user with 99 total_capacity, 7.4 rate of charge, and (7.419444444444444,1.9833333333333334) charging behavior.
# (26937, 15)
# working on user with 106 total_capacity, 11 rate of charge, and (6.247222222222222,2.0044444444444443) charging behavior.
# (26965, 15)
# working on user with 95 total_capacity, 11 rate of charge, and (7.52,2.0280555555555555) charging behavior.
# (26993, 15)
# working on user with 99 total_capacity, 22 rate of charge, and (6.741944444444444,2.1625) charging behavior.
# (27021, 15)
# working on user with 116 total_capacity, 22 rate of charge, and (8.16638888888889,2.17) charging behavior.
# (27049, 15)
# working on user with 98 total_capacity, 22 rate of charge, and (6.634166666666666,2.109722222222222) charging behavior.
# (27077, 15)
# working on user with 108 total_capacity, 22 rate of charge, and (7.203611111111111,2.0483333333333333) charging behavior.
# (27105, 15)
# working on user with 34 total_capacity, 22 rate of charge, and (5.960555555555556,2.1733333333333333) charging behavior.
# (27133, 15)
# working on user with 35 total_capacity, 11 rate of charge, and (6.821944444444444,1.931111111111111) charging behavior.
# (27161, 15)
# working on user with 83 total_capacity, 22 rate of charge, and (6.845,1.8977777777777778) charging behavior.
# (27189, 15)
# working on user with 40 total_capacity, 11 rate of charge, and (5.979166666666667,1.978888888888889) charging behavior.
# (27217, 15)
# working on user with 62 total_capacity, 7.4 rate of charge, and (7.025277777777778,2.038611111111111) charging behavior.
# (27245, 15)
# working on user with 77 total_capacity, 22 rate of charge, and (8.203333333333333,2.0347222222222223) charging behavior.
# (27273, 15)
# working on user with 78 total_capacity, 11 rate of charge, and (6.224722222222222,2.04) charging behavior.
# (27301, 15)
# working on user with 77 total_capacity, 7.4 rate of charge, and (7.4875,2.1391666666666667) charging behavior.
# (27329, 15)
# working on user with 47 total_capacity, 11 rate of charge, and (7.227777777777778,1.9736111111111112) charging behavior.
# (27357, 15)
# working on user with 50 total_capacity, 7.4 rate of charge, and (6.726111111111111,2.0044444444444443) charging behavior.
# (27385, 15)
# working on user with 39 total_capacity, 11 rate of charge, and (6.757777777777778,1.9930555555555556) charging behavior.
# (27413, 15)
# working on user with 116 total_capacity, 22 rate of charge, and (6.7811111111111115,1.8913888888888888) charging behavior.
# (27441, 15)
# working on user with 57 total_capacity, 11 rate of charge, and (6.01,2.015833333333333) charging behavior.
# (27469, 15)
# working on user with 111 total_capacity, 22 rate of charge, and (6.801666666666667,2.071111111111111) charging behavior.
# (27497, 15)
# working on user with 120 total_capacity, 7.4 rate of charge, and (7.9752777777777775,1.9805555555555556) charging behavior.
# (27525, 15)
# working on user with 67 total_capacity, 22 rate of charge, and (7.185277777777777,2.1725) charging behavior.
# (27553, 15)
# working on user with 115 total_capacity, 11 rate of charge, and (6.1177777777777775,2.2086111111111113) charging behavior.
# (27581, 15)
# working on user with 67 total_capacity, 22 rate of charge, and (7.660833333333334,2.1305555555555555) charging behavior.
# (27609, 15)
# working on user with 121 total_capacity, 7.4 rate of charge, and (7.41,2.0027777777777778) charging behavior.
# (27637, 15)
# working on user with 98 total_capacity, 22 rate of charge, and (8.100555555555555,2.104722222222222) charging behavior.
# (27665, 15)
# working on user with 120 total_capacity, 11 rate of charge, and (6.6475,2.156388888888889) charging behavior.
# (27693, 15)
# working on user with 66 total_capacity, 22 rate of charge, and (6.8902777777777775,2.006111111111111) charging behavior.
# (27721, 15)
# working on user with 90 total_capacity, 7.4 rate of charge, and (7.875277777777778,2.0838888888888887) charging behavior.
# (27749, 15)
# working on user with 112 total_capacity, 22 rate of charge, and (6.246944444444445,2.013333333333333) charging behavior.
# (27777, 15)
# working on user with 111 total_capacity, 7.4 rate of charge, and (7.568888888888889,1.9830555555555556) charging behavior.
# (27805, 15)
# working on user with 83 total_capacity, 7.4 rate of charge, and (8.193055555555556,2.0725) charging behavior.
# (27833, 15)
# working on user with 68 total_capacity, 22 rate of charge, and (6.973333333333334,2.089166666666667) charging behavior.
# (27861, 15)
# working on user with 100 total_capacity, 7.4 rate of charge, and (7.7058333333333335,2.082777777777778) charging behavior.
# (27889, 15)
# working on user with 111 total_capacity, 11 rate of charge, and (7.304444444444444,2.1358333333333333) charging behavior.
# (27917, 15)
# working on user with 45 total_capacity, 11 rate of charge, and (6.554722222222222,2.0547222222222223) charging behavior.
# (27945, 15)
# working on user with 70 total_capacity, 22 rate of charge, and (5.615555555555556,2.0166666666666666) charging behavior.
# (27973, 15)

# %%
all_users.to_csv('dummy_evaluation_data_AESO.csv')

# %%
all_users.shape
# Out:
# (27973, 15)
