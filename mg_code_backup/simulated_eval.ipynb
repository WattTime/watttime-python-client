# %%
import numpy as np
import pandas as pd
import datetime
import random
import pytz
from datetime import datetime, timedelta
import random

# %%
# utilities and functions
# get rid of this one when you get real data
def generate_normal_distribution_series(mean, variance, observations):
    std_dev = np.sqrt(variance)
    random_draws = np.random.normal(loc=mean, scale=std_dev,size=observations)
    series = pd.Series(random_draws)
    return series

def generate_random_plug_time(date):
    """
    Generate a random datetime ona the given date, uniformly distributed between 5pm and 9 pm.

    Parameters:
    date (datetime.date): The date on which to generate the random time.

    Returns:
    - datetime: A datetime object for the given date with a random time between 5 PM and 9 PM
    """
    #  Define the start and end times for the interval (5 PM to 9PM)
    start_time = datetime.combine(date, datetime.strptime("17:00:00", "%H:%M:%S").time())
    end_time = datetime.combine(date, datetime.strptime("21:00:00", "%H:%M:%S").time())
    
    # Calculate the total number of seconds between start and end times 
    total_seconds = int((end_time - start_time).total_seconds())
    
    # Generate a random number of seconds within the interval
    total_seconds = random.randint(0, total_seconds)

    # Add the random seconds to the start time to get the random datetime
    random_datetime = start_time + timedelta(seconds=total_seconds)

    random_datetime_utc = pytz.utc.localize(random_datetime)

    return random_datetime_utc

def generate_random_unplug_time(random_plug_time,mean,stddev):
    """ 
    Adds a number of sconds drawn from a normal distribution to the given datetime.

    Parameters:
    -datetime_obj
    -mean
    -stddev

    REturns 
    -pd.Timestamp: the new datetime after adding the random seconds
    """
    random_seconds = np.random.normal(loc=mean,scale=stddev)

    #convert to timedelta
    random_timedelta = timedelta(seconds=random_seconds)
    new_datetime = random_plug_time + random_timedelta

    if not isinstance(new_datetime,pd.Timestamp):
        new_datetime = pd.Timestamp(new_datetime)
    return new_datetime

# %% [markdown]
# # Mock data because the server stopped responding

# %%
start = '2023-04-01 00:00:00+00:00'
end = '2023-05-01 00:00:00+00:00'
freq = '5min'

# create some mock data because the server stopped responding
date_range = pd.date_range(start= start, end = end, freq=freq, tz='UTC')
values = generate_normal_distribution_series(1400,61,len(date_range))
df = pd.DataFrame({'point_time':date_range, 'values':values.values})

# %% [markdown]
# # Single user problem

# %%
# characterize a single user
rate= 11 #7.4, 11, or 22 kWh
total_capacity= 118 #ranges from 21kW to 123 kW
mean_length_charge = 36000 
std_length_charge = 7200

# %% [markdown]
# ### Single user/single day problem

# %% [markdown]
# For each user-day, the following dataframe summarizes their relationship with the grid:
# 1. plug_in_time : random number from a uniform distribution between 5 and 9 pm, when the user plugs in their EV
# 2. unplug_time : random number from a normal distribution with inital mean given by user (example here is 10 hours, stddev is 3 hrs)
# 3. inital_charge : what percentage of battery was full at plug in time
# 4. total seconds to 95% : how long would it take to charge the battery to the desired level
# 5. length of interval : plug_in_time - unplug_time
# 6. final battery level : how charged was the battery in the end
# 7. uncharged: boolean is the battery more than 80% full at unplug time
# 8. MOER: sum of MOER in the grid for that day (number to minimize)

# %% [markdown]
# ### Dataframe implementation: 1 user, all days for which we have data (in the mock dataframe DF)

# %%
distinct_dates = df['point_time'].dt.date.unique()
distinct_dates_utc = [pd.Timestamp(date).replace(tzinfo=pytz.UTC) for date in distinct_dates]
user_df = pd.DataFrame(distinct_dates_utc, columns=['distinct_dates']).sort_values(by='distinct_dates').copy()

# %%
user_df['user_type'] =  'r'+str(rate)+'_tc'+str(total_charge)+'_avglc'+str(mean_length_charge)+'_sdlc'+str(std_length_charge)
user_df['plug_in_time'] = user_df['distinct_dates'].apply(generate_random_plug_time)
user_df['unplug_time'] = user_df['plug_in_time'].apply(lambda x: generate_random_unplug_time(x,mean_length_charge,std_length_charge))
user_df['initial_charge'] = user_df.apply(lambda _: random.uniform(0,0.3), axis=1)
user_df['total_seconds_to_95'] = user_df['initial_charge'].apply(lambda x: total_capacity*(0.95-x)/(rate/3600))

user_df['full_charge_time']= user_df['plug_in_time'] + pd.to_timedelta(user_df['total_seconds_to_95'],unit='s')
user_df['length_plugged_in'] = (user_df.unplug_time - user_df.plug_in_time) / pd.Timedelta(seconds=1)

user_df['session_charge'] = user_df[['total_seconds_to_95','length_plugged_in']].min(axis=1)*(rate/3600)
user_df['final_perc_charged'] = user_df.session_charge.apply(lambda x: x/total_capacity)
user_df['final_perc_charged'] = user_df.final_perc_charged + user_df.initial_charge

user_df['final_charge_time'] = user_df[['full_charge_time', 'unplug_time']].min(axis=1)
user_df['uncharged'] = np.where(user_df['final_perc_charged'] <0.80, True, False)

# %%
moer_temp = user_df[['user_type','distinct_dates','plug_in_time','final_charge_time']].copy()
moer_temp['key'] = 1
df['key'] = 1

# %%
moer_temp = pd.merge(moer_temp,df, on='key').drop(columns='key')
moer_temp = moer_temp[(moer_temp['point_time']>moer_temp['plug_in_time'])&(moer_temp['point_time']<moer_temp['final_charge_time'])]

# %%
moer_temp = moer_temp.groupby(['distinct_dates','user_type']).agg(
    sum_moer=('values','sum'),
    count_moer_intervals=('values','count'),
    avg_moer=('values','mean')
).reset_index()

# %%
user_df= pd.merge(user_df,moer_temp, on=['user_type','distinct_dates'])

# %%
user_df.to_csv('test.csv')

# %%
i = user_df.loc[3]

# %%
f"For user {i['user_type']}, on date {i['distinct_dates']}, the EV was plugged in at {i['plug_in_time']}, and unplugged at {i['unplug_time']}.It had an initial charge of {i['initial_charge']:.1%}. At max rate, full charge time would be {i['full_charge_time']}. This leaves it with a final charge of {i['final_perc_charged']}. The total MOER was {i['sum_moer']:,}"
# Out:
# 'For user r11_tc118_avglc36000_sdlc7200, on date 2023-04-04 00:00:00+00:00, the EV was plugged in at 2023-04-04 19:19:30+00:00, and unplugged at 2023-04-05 06:23:08.383185+00:00.It had an initial charge of 17.7%. At max rate, full charge time would be 2023-04-05 03:37:09.515708351+00:00. This leaves it with a final charge of 0.9499999999999998. The total MOER was 140,027.74590956327'

# %% [markdown]
# # Simulate 1K users to get a distribution

# %%
all_users = pd.DataFrame()
for i in range(1000):
    rate = random.choice([11,7.4,22])
    total_capacity =  round(random.uniform(21,123))
    mean_length_charge = round(random.uniform(20000,30000))
    std_length_charge = round(random.uniform(6800,8000))
    
    print(f"working on user with {total_capacity} total_capacity, {rate} rate of charge, and ({mean_length_charge/3600},{std_length_charge/3600}) charging behavior.") 

    user_df = pd.DataFrame(distinct_dates_utc, columns=['distinct_dates']).sort_values(by='distinct_dates').copy() 

    user_df['user_type'] =  'r'+str(rate)+'_tc'+str(total_charge)+'_avglc'+str(mean_length_charge)+'_sdlc'+str(std_length_charge)
    user_df['plug_in_time'] = user_df['distinct_dates'].apply(generate_random_plug_time)
    user_df['unplug_time'] = user_df['plug_in_time'].apply(lambda x: generate_random_unplug_time(x,mean_length_charge,std_length_charge))
    user_df['initial_charge'] = user_df.apply(lambda _: random.uniform(0,0.3), axis=1)
    user_df['total_seconds_to_95'] = user_df['initial_charge'].apply(lambda x: total_capacity*(0.95-x)/(rate/3600))
    
    user_df['full_charge_time']= user_df['plug_in_time'] + pd.to_timedelta(user_df['total_seconds_to_95'],unit='s')
    user_df['length_plugged_in'] = (user_df.unplug_time - user_df.plug_in_time) / pd.Timedelta(seconds=1)
    
    user_df['session_charge'] = user_df[['total_seconds_to_95','length_plugged_in']].min(axis=1)*(rate/3600)
    user_df['final_perc_charged'] = user_df.session_charge.apply(lambda x: x/total_capacity)
    user_df['final_perc_charged'] = user_df.final_perc_charged + user_df.initial_charge
    
    user_df['final_charge_time'] = user_df[['full_charge_time', 'unplug_time']].min(axis=1)
    user_df['uncharged'] = np.where(user_df['final_perc_charged'] <0.80, True, False)

    moer_temp = user_df[['user_type','distinct_dates','plug_in_time','final_charge_time']].copy()
    moer_temp['key'] = 1
    df['key'] = 1

    moer_temp = pd.merge(moer_temp,df, on='key').drop(columns='key')
    moer_temp = moer_temp[(moer_temp['point_time']>moer_temp['plug_in_time'])&(moer_temp['point_time']<moer_temp['final_charge_time'])]

    moer_temp = moer_temp.groupby(['distinct_dates','user_type']).agg(
        sum_moer=('values','sum'),
        count_moer_intervals=('values','count'),
        avg_moer=('values','mean')
    ).reset_index()

    user_df= pd.merge(user_df,moer_temp, on=['user_type','distinct_dates'])
    all_users = pd.concat([all_users, user_df], axis=0)
    print(all_users.shape)
# Out:
# working on user with 36 total_capacity, 22 rate of charge, and (6.634166666666666,1.9833333333333334) charging behavior.
# (30, 15)
# working on user with 52 total_capacity, 7.4 rate of charge, and (6.380833333333333,1.9541666666666666) charging behavior.
# (60, 15)
# working on user with 85 total_capacity, 11 rate of charge, and (5.883333333333334,2.1025) charging behavior.
# (90, 15)
# working on user with 22 total_capacity, 11 rate of charge, and (6.065277777777778,2.2119444444444443) charging behavior.
# (120, 15)
# working on user with 94 total_capacity, 7.4 rate of charge, and (6.9225,1.9325) charging behavior.
# (150, 15)
# working on user with 59 total_capacity, 11 rate of charge, and (7.726111111111111,2.019722222222222) charging behavior.
# (180, 15)
# working on user with 94 total_capacity, 7.4 rate of charge, and (5.809444444444445,2.118611111111111) charging behavior.
# (210, 15)
# working on user with 96 total_capacity, 11 rate of charge, and (8.147222222222222,1.9152777777777779) charging behavior.
# (240, 15)
# working on user with 32 total_capacity, 22 rate of charge, and (7.048611111111111,2.0755555555555554) charging behavior.
# (270, 15)
# working on user with 70 total_capacity, 11 rate of charge, and (5.728611111111111,2.0458333333333334) charging behavior.
# (300, 15)
# working on user with 119 total_capacity, 22 rate of charge, and (6.776944444444444,2.0941666666666667) charging behavior.
# (330, 15)
# working on user with 30 total_capacity, 11 rate of charge, and (7.338611111111111,2.0619444444444444) charging behavior.
# (360, 15)
# working on user with 40 total_capacity, 11 rate of charge, and (5.816388888888889,2.004722222222222) charging behavior.
# (390, 15)
# working on user with 116 total_capacity, 7.4 rate of charge, and (6.758055555555556,2.0213888888888887) charging behavior.
# (420, 15)
# working on user with 22 total_capacity, 11 rate of charge, and (6.243055555555555,1.938611111111111) charging behavior.
# (450, 15)
# working on user with 66 total_capacity, 11 rate of charge, and (5.6691666666666665,1.99) charging behavior.
# (480, 15)
# working on user with 32 total_capacity, 22 rate of charge, and (6.546388888888889,2.125) charging behavior.
# (510, 15)
# working on user with 40 total_capacity, 7.4 rate of charge, and (7.220555555555555,2.0369444444444444) charging behavior.
# (540, 15)
# working on user with 48 total_capacity, 22 rate of charge, and (6.984166666666667,2.1347222222222224) charging behavior.
# (570, 15)
# working on user with 51 total_capacity, 22 rate of charge, and (5.836666666666667,2.1533333333333333) charging behavior.
# (600, 15)
# working on user with 70 total_capacity, 22 rate of charge, and (7.779166666666667,2.185) charging behavior.
# (630, 15)
# working on user with 74 total_capacity, 7.4 rate of charge, and (7.3475,1.9716666666666667) charging behavior.
# (660, 15)
# working on user with 24 total_capacity, 11 rate of charge, and (7.542222222222223,1.961111111111111) charging behavior.
# (690, 15)
# working on user with 97 total_capacity, 22 rate of charge, and (6.4430555555555555,2.109722222222222) charging behavior.
# (720, 15)
# working on user with 82 total_capacity, 7.4 rate of charge, and (5.9875,2.160833333333333) charging behavior.
# (750, 15)
# working on user with 96 total_capacity, 7.4 rate of charge, and (6.2525,2.015833333333333) charging behavior.
# (780, 15)
# working on user with 106 total_capacity, 22 rate of charge, and (5.766111111111111,2.198611111111111) charging behavior.
# (810, 15)
# working on user with 90 total_capacity, 11 rate of charge, and (5.9622222222222225,2.053888888888889) charging behavior.
# (840, 15)
# working on user with 35 total_capacity, 11 rate of charge, and (6.450277777777778,2.1130555555555555) charging behavior.
# (870, 15)
# working on user with 79 total_capacity, 22 rate of charge, and (8.153611111111111,2.0566666666666666) charging behavior.
# (900, 15)
# working on user with 108 total_capacity, 7.4 rate of charge, and (7.2427777777777775,1.9625) charging behavior.
# (930, 15)
# working on user with 96 total_capacity, 7.4 rate of charge, and (6.270277777777777,1.9655555555555555) charging behavior.
# (960, 15)
# working on user with 33 total_capacity, 7.4 rate of charge, and (6.275555555555556,2.1772222222222224) charging behavior.
# (990, 15)
# working on user with 105 total_capacity, 22 rate of charge, and (8.04888888888889,1.9447222222222222) charging behavior.
# (1020, 15)
# working on user with 25 total_capacity, 22 rate of charge, and (6.8902777777777775,1.9758333333333333) charging behavior.
# (1050, 15)
# working on user with 31 total_capacity, 7.4 rate of charge, and (7.968055555555556,2.056388888888889) charging behavior.
# (1080, 15)
# working on user with 111 total_capacity, 7.4 rate of charge, and (7.032222222222222,1.965) charging behavior.
# (1110, 15)
# working on user with 40 total_capacity, 22 rate of charge, and (5.711111111111111,2.0522222222222224) charging behavior.
# (1140, 15)
# working on user with 112 total_capacity, 11 rate of charge, and (7.495555555555556,2.1169444444444445) charging behavior.
# (1170, 15)
# working on user with 36 total_capacity, 11 rate of charge, and (5.638055555555556,2.082777777777778) charging behavior.
# (1200, 15)
# working on user with 115 total_capacity, 7.4 rate of charge, and (7.655555555555556,2.0661111111111112) charging behavior.
# (1230, 15)
# working on user with 25 total_capacity, 22 rate of charge, and (7.460277777777778,1.9919444444444445) charging behavior.
# (1260, 15)
# working on user with 59 total_capacity, 11 rate of charge, and (7.415277777777778,2.0436111111111113) charging behavior.
# (1290, 15)
# working on user with 94 total_capacity, 22 rate of charge, and (5.762222222222222,2.046666666666667) charging behavior.
# (1320, 15)
# working on user with 23 total_capacity, 11 rate of charge, and (5.915,2.1733333333333333) charging behavior.
# (1350, 15)
# working on user with 72 total_capacity, 22 rate of charge, and (7.350833333333333,2.091666666666667) charging behavior.
# (1380, 15)
# working on user with 55 total_capacity, 22 rate of charge, and (7.998888888888889,2.015) charging behavior.
# (1410, 15)
# working on user with 97 total_capacity, 11 rate of charge, and (7.335555555555556,2.151111111111111) charging behavior.
# (1440, 15)
# working on user with 57 total_capacity, 7.4 rate of charge, and (7.722222222222222,1.8966666666666667) charging behavior.
# (1470, 15)
# working on user with 100 total_capacity, 22 rate of charge, and (5.723055555555556,2.1372222222222224) charging behavior.
# (1500, 15)
# working on user with 77 total_capacity, 11 rate of charge, and (5.77,2.2130555555555556) charging behavior.
# (1530, 15)
# working on user with 82 total_capacity, 7.4 rate of charge, and (7.921666666666667,2.173888888888889) charging behavior.
# (1560, 15)
# working on user with 89 total_capacity, 7.4 rate of charge, and (6.076388888888889,1.9691666666666667) charging behavior.
# (1590, 15)
# working on user with 113 total_capacity, 11 rate of charge, and (5.578888888888889,2.1191666666666666) charging behavior.
# (1620, 15)
# working on user with 75 total_capacity, 11 rate of charge, and (6.5152777777777775,2.0130555555555554) charging behavior.
# (1650, 15)
# working on user with 113 total_capacity, 7.4 rate of charge, and (5.7188888888888885,2.078611111111111) charging behavior.
# (1680, 15)
# working on user with 111 total_capacity, 11 rate of charge, and (5.933611111111111,2.0605555555555557) charging behavior.
# (1710, 15)
# working on user with 93 total_capacity, 22 rate of charge, and (6.3975,1.9402777777777778) charging behavior.
# (1740, 15)
# working on user with 89 total_capacity, 7.4 rate of charge, and (6.9125,1.9661111111111111) charging behavior.
# (1770, 15)
# working on user with 100 total_capacity, 22 rate of charge, and (7.164166666666667,2.0944444444444446) charging behavior.
# (1800, 15)
# working on user with 88 total_capacity, 22 rate of charge, and (7.250277777777778,2.0394444444444444) charging behavior.
# (1830, 15)
# working on user with 61 total_capacity, 7.4 rate of charge, and (7.604722222222223,2.2197222222222224) charging behavior.
# (1860, 15)
# working on user with 99 total_capacity, 11 rate of charge, and (6.513055555555556,2.0516666666666667) charging behavior.
# (1890, 15)
# working on user with 49 total_capacity, 7.4 rate of charge, and (7.895,1.9816666666666667) charging behavior.
# (1920, 15)
# working on user with 86 total_capacity, 11 rate of charge, and (6.406944444444444,2.0566666666666666) charging behavior.
# (1950, 15)
# working on user with 69 total_capacity, 22 rate of charge, and (5.752777777777778,1.898611111111111) charging behavior.
# (1980, 15)
# working on user with 88 total_capacity, 11 rate of charge, and (8.271944444444445,1.9030555555555555) charging behavior.
# (2010, 15)
# working on user with 31 total_capacity, 22 rate of charge, and (6.594444444444444,2.0380555555555557) charging behavior.
# (2040, 15)
# working on user with 57 total_capacity, 7.4 rate of charge, and (7.19,1.9447222222222222) charging behavior.
# (2070, 15)
# working on user with 106 total_capacity, 22 rate of charge, and (6.8425,2.075) charging behavior.
# (2100, 15)
# working on user with 37 total_capacity, 22 rate of charge, and (6.785555555555556,2.0927777777777776) charging behavior.
# (2130, 15)
# working on user with 65 total_capacity, 22 rate of charge, and (6.081388888888889,2.0280555555555555) charging behavior.
# (2160, 15)
# working on user with 107 total_capacity, 7.4 rate of charge, and (7.809444444444445,2.013888888888889) charging behavior.
# (2190, 15)
# working on user with 43 total_capacity, 22 rate of charge, and (5.703888888888889,2.0994444444444444) charging behavior.
# (2220, 15)
# working on user with 45 total_capacity, 7.4 rate of charge, and (7.44,2.0244444444444443) charging behavior.
# (2250, 15)
# working on user with 100 total_capacity, 22 rate of charge, and (7.6475,2.035) charging behavior.
# (2280, 15)
# working on user with 68 total_capacity, 22 rate of charge, and (5.5936111111111115,2.2127777777777777) charging behavior.
# (2310, 15)
# working on user with 42 total_capacity, 11 rate of charge, and (7.651666666666666,2.1580555555555554) charging behavior.
# (2340, 15)
# working on user with 34 total_capacity, 7.4 rate of charge, and (6.0152777777777775,2.1330555555555555) charging behavior.
# (2370, 15)
# working on user with 60 total_capacity, 22 rate of charge, and (6.306666666666667,2.0625) charging behavior.
# (2400, 15)
# working on user with 45 total_capacity, 7.4 rate of charge, and (7.4255555555555555,2.042222222222222) charging behavior.
# (2430, 15)
# working on user with 93 total_capacity, 11 rate of charge, and (8.329722222222221,2.151666666666667) charging behavior.
# (2460, 15)
# working on user with 75 total_capacity, 11 rate of charge, and (7.040277777777778,2.031388888888889) charging behavior.
# (2490, 15)
# working on user with 67 total_capacity, 11 rate of charge, and (7.473888888888889,2.0836111111111113) charging behavior.
# (2520, 15)
# working on user with 66 total_capacity, 11 rate of charge, and (7.4325,2.1166666666666667) charging behavior.
# (2550, 15)
# working on user with 106 total_capacity, 7.4 rate of charge, and (7.243888888888889,2.1958333333333333) charging behavior.
# (2580, 15)
# working on user with 53 total_capacity, 11 rate of charge, and (7.032777777777778,2.0652777777777778) charging behavior.
# (2610, 15)
# working on user with 52 total_capacity, 11 rate of charge, and (8.0325,2.028611111111111) charging behavior.
# (2640, 15)
# working on user with 55 total_capacity, 22 rate of charge, and (7.207777777777777,2.0166666666666666) charging behavior.
# (2670, 15)
# working on user with 67 total_capacity, 11 rate of charge, and (8.186666666666667,2.0702777777777777) charging behavior.
# (2700, 15)
# working on user with 114 total_capacity, 7.4 rate of charge, and (7.403611111111111,1.9852777777777777) charging behavior.
# (2730, 15)
# working on user with 53 total_capacity, 11 rate of charge, and (6.653611111111111,2.071111111111111) charging behavior.
# (2760, 15)
# working on user with 113 total_capacity, 22 rate of charge, and (5.981111111111111,1.9113888888888888) charging behavior.
# (2790, 15)
# working on user with 123 total_capacity, 11 rate of charge, and (8.269722222222223,2.0216666666666665) charging behavior.
# (2820, 15)
# working on user with 25 total_capacity, 22 rate of charge, and (7.913055555555555,2.0330555555555554) charging behavior.
# (2850, 15)
# working on user with 100 total_capacity, 7.4 rate of charge, and (7.067777777777778,1.9211111111111112) charging behavior.
# (2880, 15)
# working on user with 52 total_capacity, 22 rate of charge, and (7.058888888888889,2.0341666666666667) charging behavior.
# (2910, 15)
# working on user with 54 total_capacity, 11 rate of charge, and (7.716111111111111,2.1544444444444446) charging behavior.
# (2939, 15)
# working on user with 22 total_capacity, 22 rate of charge, and (7.065277777777778,2.069166666666667) charging behavior.
# (2969, 15)
# working on user with 94 total_capacity, 11 rate of charge, and (8.046944444444444,2.195) charging behavior.
# (2999, 15)
# working on user with 122 total_capacity, 11 rate of charge, and (8.2625,1.8975) charging behavior.
# (3029, 15)
# working on user with 109 total_capacity, 7.4 rate of charge, and (7.597777777777778,2.0355555555555553) charging behavior.
# (3059, 15)
# working on user with 104 total_capacity, 7.4 rate of charge, and (6.788611111111111,2.026666666666667) charging behavior.
# (3089, 15)
# working on user with 53 total_capacity, 11 rate of charge, and (7.7325,2.062777777777778) charging behavior.
# (3119, 15)
# working on user with 108 total_capacity, 22 rate of charge, and (7.416944444444445,2.196111111111111) charging behavior.
# (3149, 15)
# working on user with 107 total_capacity, 11 rate of charge, and (6.982777777777778,2.0255555555555556) charging behavior.
# (3178, 15)
# working on user with 108 total_capacity, 22 rate of charge, and (7.2975,2.141388888888889) charging behavior.
# (3208, 15)
# working on user with 71 total_capacity, 7.4 rate of charge, and (7.839722222222222,2.0575) charging behavior.
# (3238, 15)
# working on user with 33 total_capacity, 7.4 rate of charge, and (5.768888888888889,2.1525) charging behavior.
# (3268, 15)
# working on user with 62 total_capacity, 7.4 rate of charge, and (5.621666666666667,1.9736111111111112) charging behavior.
# (3298, 15)
# working on user with 113 total_capacity, 11 rate of charge, and (5.865555555555556,1.895) charging behavior.
# (3328, 15)
# working on user with 82 total_capacity, 7.4 rate of charge, and (7.902222222222222,2.035) charging behavior.
# (3358, 15)
# working on user with 29 total_capacity, 11 rate of charge, and (5.724444444444444,1.9436111111111112) charging behavior.
# (3388, 15)
# working on user with 78 total_capacity, 22 rate of charge, and (6.502777777777778,2.1780555555555554) charging behavior.
# (3418, 15)
# working on user with 38 total_capacity, 7.4 rate of charge, and (6.163055555555555,2.220833333333333) charging behavior.
# (3448, 15)
# working on user with 93 total_capacity, 22 rate of charge, and (6.879444444444444,2.176111111111111) charging behavior.
# (3478, 15)
# working on user with 25 total_capacity, 7.4 rate of charge, and (6.193333333333333,1.9111111111111112) charging behavior.
# (3508, 15)
# working on user with 109 total_capacity, 11 rate of charge, and (7.9725,2.163611111111111) charging behavior.
# (3538, 15)
# working on user with 34 total_capacity, 7.4 rate of charge, and (7.970555555555555,2.1422222222222222) charging behavior.
# (3568, 15)
# working on user with 25 total_capacity, 22 rate of charge, and (5.73,1.9475) charging behavior.
# (3598, 15)
# working on user with 79 total_capacity, 7.4 rate of charge, and (7.228055555555556,2.03) charging behavior.
# (3628, 15)
# working on user with 107 total_capacity, 11 rate of charge, and (8.290277777777778,1.913888888888889) charging behavior.
# (3658, 15)
# working on user with 27 total_capacity, 11 rate of charge, and (7.265833333333333,2.0555555555555554) charging behavior.
# (3688, 15)
# working on user with 116 total_capacity, 7.4 rate of charge, and (6.097222222222222,2.1619444444444444) charging behavior.
# (3718, 15)
# working on user with 98 total_capacity, 22 rate of charge, and (5.601944444444444,2.1933333333333334) charging behavior.
# (3748, 15)
# working on user with 66 total_capacity, 11 rate of charge, and (6.165277777777778,1.9894444444444443) charging behavior.
# (3778, 15)
# working on user with 101 total_capacity, 22 rate of charge, and (8.165833333333333,2.0391666666666666) charging behavior.
# (3808, 15)
# working on user with 32 total_capacity, 22 rate of charge, and (7.0488888888888885,2.0141666666666667) charging behavior.
# (3838, 15)
# working on user with 89 total_capacity, 22 rate of charge, and (7.0247222222222225,2.006666666666667) charging behavior.
# (3868, 15)
# working on user with 63 total_capacity, 7.4 rate of charge, and (7.168333333333333,2.044722222222222) charging behavior.
# (3898, 15)
# working on user with 33 total_capacity, 22 rate of charge, and (6.354444444444445,2.1894444444444443) charging behavior.
# (3928, 15)
# working on user with 112 total_capacity, 11 rate of charge, and (6.951944444444444,1.978888888888889) charging behavior.
# (3958, 15)
# working on user with 70 total_capacity, 22 rate of charge, and (8.26388888888889,1.93) charging behavior.
# (3988, 15)
# working on user with 63 total_capacity, 11 rate of charge, and (7.739722222222222,2.0388888888888888) charging behavior.
# (4018, 15)
# working on user with 108 total_capacity, 22 rate of charge, and (6.999444444444444,1.9366666666666668) charging behavior.
# (4048, 15)
# working on user with 46 total_capacity, 7.4 rate of charge, and (7.352777777777778,2.18) charging behavior.
# (4078, 15)
# working on user with 36 total_capacity, 22 rate of charge, and (6.633055555555556,2.1358333333333333) charging behavior.
# (4108, 15)
# working on user with 44 total_capacity, 11 rate of charge, and (6.676944444444445,2.081111111111111) charging behavior.
# (4138, 15)
# working on user with 60 total_capacity, 11 rate of charge, and (6.458611111111111,2.132222222222222) charging behavior.
# (4168, 15)
# working on user with 70 total_capacity, 11 rate of charge, and (8.017777777777777,2.073888888888889) charging behavior.
# (4198, 15)
# working on user with 74 total_capacity, 7.4 rate of charge, and (6.943888888888889,2.0280555555555555) charging behavior.
# (4228, 15)
# working on user with 25 total_capacity, 7.4 rate of charge, and (6.194444444444445,2.18) charging behavior.
# (4258, 15)
# working on user with 73 total_capacity, 11 rate of charge, and (7.941666666666666,2.0452777777777778) charging behavior.
# (4288, 15)
# working on user with 90 total_capacity, 11 rate of charge, and (7.123333333333333,2.0597222222222222) charging behavior.
# (4318, 15)
# working on user with 96 total_capacity, 11 rate of charge, and (7.671666666666667,2.185277777777778) charging behavior.
# (4348, 15)
# working on user with 96 total_capacity, 7.4 rate of charge, and (8.046944444444444,2.218611111111111) charging behavior.
# (4378, 15)
# working on user with 47 total_capacity, 7.4 rate of charge, and (6.125,1.9566666666666668) charging behavior.
# (4408, 15)
# working on user with 71 total_capacity, 22 rate of charge, and (6.123055555555555,2.1013888888888888) charging behavior.
# (4438, 15)
# working on user with 78 total_capacity, 7.4 rate of charge, and (7.987777777777778,2.168888888888889) charging behavior.
# (4468, 15)
# working on user with 36 total_capacity, 7.4 rate of charge, and (8.300833333333333,2.172222222222222) charging behavior.
# (4498, 15)
# working on user with 27 total_capacity, 7.4 rate of charge, and (8.135,2.0208333333333335) charging behavior.
# (4528, 15)
# working on user with 103 total_capacity, 22 rate of charge, and (6.742222222222222,2.116111111111111) charging behavior.
# (4558, 15)
# working on user with 31 total_capacity, 7.4 rate of charge, and (7.795833333333333,2.1683333333333334) charging behavior.
# (4588, 15)
# working on user with 40 total_capacity, 7.4 rate of charge, and (6.446111111111111,2.121111111111111) charging behavior.
# (4618, 15)
# working on user with 73 total_capacity, 22 rate of charge, and (5.791111111111111,2.076388888888889) charging behavior.
# (4648, 15)
# working on user with 73 total_capacity, 7.4 rate of charge, and (7.846111111111111,2.0797222222222222) charging behavior.
# (4678, 15)
# working on user with 62 total_capacity, 22 rate of charge, and (5.642222222222222,2.2144444444444447) charging behavior.
# (4708, 15)
# working on user with 79 total_capacity, 7.4 rate of charge, and (6.036111111111111,2.1638888888888888) charging behavior.
# (4737, 15)
# working on user with 55 total_capacity, 22 rate of charge, and (6.527777777777778,2.175) charging behavior.
# (4767, 15)
# working on user with 95 total_capacity, 22 rate of charge, and (7.991666666666666,2.2022222222222223) charging behavior.
# (4797, 15)
# working on user with 122 total_capacity, 7.4 rate of charge, and (6.4688888888888885,2.101111111111111) charging behavior.
# (4827, 15)
# working on user with 93 total_capacity, 22 rate of charge, and (6.456111111111111,1.9922222222222221) charging behavior.
# (4857, 15)
# working on user with 106 total_capacity, 7.4 rate of charge, and (7.248333333333333,2.0097222222222224) charging behavior.
# (4887, 15)
# working on user with 86 total_capacity, 7.4 rate of charge, and (7.945277777777778,1.9752777777777777) charging behavior.
# (4917, 15)
# working on user with 64 total_capacity, 22 rate of charge, and (7.0247222222222225,1.9697222222222222) charging behavior.
# (4947, 15)
# working on user with 21 total_capacity, 22 rate of charge, and (7.570833333333334,2.136111111111111) charging behavior.
# (4977, 15)
# working on user with 80 total_capacity, 22 rate of charge, and (6.5975,2.1458333333333335) charging behavior.
# (5007, 15)
# working on user with 92 total_capacity, 22 rate of charge, and (6.6325,2.0280555555555555) charging behavior.
# (5037, 15)
# working on user with 63 total_capacity, 7.4 rate of charge, and (7.536666666666667,2.188888888888889) charging behavior.
# (5067, 15)
# working on user with 55 total_capacity, 7.4 rate of charge, and (5.571111111111111,2.0188888888888887) charging behavior.
# (5097, 15)
# working on user with 26 total_capacity, 22 rate of charge, and (6.192222222222222,1.9458333333333333) charging behavior.
# (5127, 15)
# working on user with 44 total_capacity, 7.4 rate of charge, and (6.601944444444444,1.9022222222222223) charging behavior.
# (5157, 15)
# working on user with 76 total_capacity, 22 rate of charge, and (6.6161111111111115,2.085) charging behavior.
# (5187, 15)
# working on user with 25 total_capacity, 7.4 rate of charge, and (7.611944444444444,2.1333333333333333) charging behavior.
# (5217, 15)
# working on user with 95 total_capacity, 11 rate of charge, and (6.544444444444444,2.1630555555555557) charging behavior.
# (5247, 15)
# working on user with 98 total_capacity, 22 rate of charge, and (8.230555555555556,2.1894444444444443) charging behavior.
# (5277, 15)
# working on user with 90 total_capacity, 11 rate of charge, and (6.055555555555555,1.9041666666666666) charging behavior.
# (5307, 15)
# working on user with 87 total_capacity, 11 rate of charge, and (5.87,1.8925) charging behavior.
# (5337, 15)
# working on user with 79 total_capacity, 22 rate of charge, and (5.658611111111111,2.195) charging behavior.
# (5366, 15)
# working on user with 44 total_capacity, 22 rate of charge, and (7.658055555555555,2.102777777777778) charging behavior.
# (5396, 15)
# working on user with 80 total_capacity, 11 rate of charge, and (5.619166666666667,2.151388888888889) charging behavior.
# (5426, 15)
# working on user with 60 total_capacity, 22 rate of charge, and (7.642222222222222,2.1661111111111113) charging behavior.
# (5456, 15)
# working on user with 76 total_capacity, 7.4 rate of charge, and (8.245555555555555,2.091111111111111) charging behavior.
# (5486, 15)
# working on user with 119 total_capacity, 22 rate of charge, and (6.049722222222222,2.093611111111111) charging behavior.
# (5516, 15)
# working on user with 53 total_capacity, 7.4 rate of charge, and (7.856111111111111,2.1319444444444446) charging behavior.
# (5546, 15)
# working on user with 107 total_capacity, 11 rate of charge, and (5.958055555555555,2.057777777777778) charging behavior.
# (5576, 15)
# working on user with 111 total_capacity, 7.4 rate of charge, and (7.114722222222222,1.9775) charging behavior.
# (5606, 15)
# working on user with 59 total_capacity, 11 rate of charge, and (7.630277777777778,2.1175) charging behavior.
# (5636, 15)
# working on user with 59 total_capacity, 22 rate of charge, and (6.297777777777778,2.0533333333333332) charging behavior.
# (5666, 15)
# working on user with 65 total_capacity, 22 rate of charge, and (7.921388888888889,1.9633333333333334) charging behavior.
# (5696, 15)
# working on user with 80 total_capacity, 22 rate of charge, and (6.551111111111111,1.9636111111111112) charging behavior.
# (5726, 15)
# working on user with 43 total_capacity, 22 rate of charge, and (6.991666666666666,2.132222222222222) charging behavior.
# (5756, 15)
# working on user with 40 total_capacity, 7.4 rate of charge, and (8.015277777777778,1.9119444444444444) charging behavior.
# (5786, 15)
# working on user with 56 total_capacity, 7.4 rate of charge, and (6.954722222222222,2.0383333333333336) charging behavior.
# (5816, 15)
# working on user with 54 total_capacity, 22 rate of charge, and (7.661944444444444,1.9277777777777778) charging behavior.
# (5846, 15)
# working on user with 30 total_capacity, 22 rate of charge, and (7.55,2.0655555555555556) charging behavior.
# (5876, 15)
# working on user with 91 total_capacity, 22 rate of charge, and (7.584444444444444,2.0730555555555554) charging behavior.
# (5906, 15)
# working on user with 71 total_capacity, 7.4 rate of charge, and (7.944166666666667,2.1552777777777776) charging behavior.
# (5936, 15)
# working on user with 84 total_capacity, 22 rate of charge, and (5.914444444444444,1.9927777777777778) charging behavior.
# (5966, 15)
# working on user with 121 total_capacity, 22 rate of charge, and (7.796111111111111,2.1505555555555556) charging behavior.
# (5996, 15)
# working on user with 30 total_capacity, 11 rate of charge, and (7.379722222222222,2.0030555555555556) charging behavior.
# (6026, 15)
# working on user with 112 total_capacity, 7.4 rate of charge, and (7.7555555555555555,2.203611111111111) charging behavior.
# (6056, 15)
# working on user with 82 total_capacity, 22 rate of charge, and (7.4875,1.9597222222222221) charging behavior.
# (6086, 15)
# working on user with 63 total_capacity, 22 rate of charge, and (6.938611111111111,2.0316666666666667) charging behavior.
# (6116, 15)
# working on user with 66 total_capacity, 7.4 rate of charge, and (6.7925,2.08) charging behavior.
# (6146, 15)
# working on user with 63 total_capacity, 11 rate of charge, and (8.206666666666667,2.045) charging behavior.
# (6176, 15)
# working on user with 80 total_capacity, 7.4 rate of charge, and (7.835555555555556,2.0211111111111113) charging behavior.
# (6206, 15)
# working on user with 53 total_capacity, 7.4 rate of charge, and (8.001666666666667,2.0194444444444444) charging behavior.
# (6236, 15)
# working on user with 79 total_capacity, 7.4 rate of charge, and (7.408611111111111,2.003888888888889) charging behavior.
# (6266, 15)
# working on user with 77 total_capacity, 7.4 rate of charge, and (5.82,2.037777777777778) charging behavior.
# (6296, 15)
# working on user with 120 total_capacity, 22 rate of charge, and (6.7636111111111115,2.0294444444444446) charging behavior.
# (6326, 15)
# working on user with 91 total_capacity, 22 rate of charge, and (7.37,2.0166666666666666) charging behavior.
# (6356, 15)
# working on user with 49 total_capacity, 7.4 rate of charge, and (7.7988888888888885,2.0366666666666666) charging behavior.
# (6386, 15)
# working on user with 30 total_capacity, 7.4 rate of charge, and (6.3933333333333335,2.1308333333333334) charging behavior.
# (6416, 15)
# working on user with 90 total_capacity, 7.4 rate of charge, and (6.900833333333333,2.131111111111111) charging behavior.
# (6446, 15)
# working on user with 58 total_capacity, 22 rate of charge, and (7.188055555555556,2.2158333333333333) charging behavior.
# (6476, 15)
# working on user with 24 total_capacity, 11 rate of charge, and (7.390833333333333,2.1572222222222224) charging behavior.
# (6506, 15)
# working on user with 110 total_capacity, 7.4 rate of charge, and (7.302777777777778,2.0280555555555555) charging behavior.
# (6536, 15)
# working on user with 71 total_capacity, 11 rate of charge, and (5.789444444444444,2.117777777777778) charging behavior.
# (6566, 15)
# working on user with 29 total_capacity, 22 rate of charge, and (5.579166666666667,1.9280555555555556) charging behavior.
# (6596, 15)
# working on user with 95 total_capacity, 11 rate of charge, and (6.338888888888889,2.2152777777777777) charging behavior.
# (6626, 15)
# working on user with 99 total_capacity, 22 rate of charge, and (5.963888888888889,2.066666666666667) charging behavior.
# (6656, 15)
# working on user with 82 total_capacity, 22 rate of charge, and (5.774444444444445,2.0219444444444443) charging behavior.
# (6686, 15)
# working on user with 24 total_capacity, 22 rate of charge, and (7.5552777777777775,1.9975) charging behavior.
# (6716, 15)
# working on user with 90 total_capacity, 7.4 rate of charge, and (7.921944444444445,2.203611111111111) charging behavior.
# (6746, 15)
# working on user with 91 total_capacity, 11 rate of charge, and (7.939722222222223,1.9641666666666666) charging behavior.
# (6776, 15)
# working on user with 95 total_capacity, 22 rate of charge, and (6.026111111111111,1.9027777777777777) charging behavior.
# (6806, 15)
# working on user with 107 total_capacity, 22 rate of charge, and (7.745,2.1894444444444443) charging behavior.
# (6836, 15)
# working on user with 52 total_capacity, 7.4 rate of charge, and (6.307222222222222,2.12) charging behavior.
# (6866, 15)
# working on user with 40 total_capacity, 7.4 rate of charge, and (7.598333333333334,1.9544444444444444) charging behavior.
# (6896, 15)
# working on user with 92 total_capacity, 11 rate of charge, and (7.293611111111111,1.9908333333333332) charging behavior.
# (6926, 15)
# working on user with 42 total_capacity, 7.4 rate of charge, and (6.743611111111111,1.9641666666666666) charging behavior.
# (6956, 15)
# working on user with 68 total_capacity, 11 rate of charge, and (6.049166666666666,2.008888888888889) charging behavior.
# (6986, 15)
# working on user with 78 total_capacity, 7.4 rate of charge, and (7.509444444444444,2.1475) charging behavior.
# (7016, 15)
# working on user with 116 total_capacity, 11 rate of charge, and (8.226666666666667,2.12) charging behavior.
# (7046, 15)
# working on user with 62 total_capacity, 7.4 rate of charge, and (6.691944444444444,2.026666666666667) charging behavior.
# (7076, 15)
# working on user with 42 total_capacity, 11 rate of charge, and (6.311944444444444,2.1233333333333335) charging behavior.
# (7106, 15)
# working on user with 105 total_capacity, 22 rate of charge, and (7.321111111111111,1.9997222222222222) charging behavior.
# (7136, 15)
# working on user with 59 total_capacity, 22 rate of charge, and (6.1994444444444445,2.0669444444444443) charging behavior.
# (7166, 15)
# working on user with 74 total_capacity, 11 rate of charge, and (6.0425,2.216666666666667) charging behavior.
# (7196, 15)
# working on user with 69 total_capacity, 7.4 rate of charge, and (7.407777777777778,2.1491666666666664) charging behavior.
# (7226, 15)
# working on user with 45 total_capacity, 22 rate of charge, and (7.186388888888889,1.9280555555555556) charging behavior.
# (7256, 15)
# working on user with 115 total_capacity, 7.4 rate of charge, and (6.3261111111111115,2.200833333333333) charging behavior.
# (7286, 15)
# working on user with 62 total_capacity, 22 rate of charge, and (5.899166666666667,2.200277777777778) charging behavior.
# (7316, 15)
# working on user with 104 total_capacity, 22 rate of charge, and (7.332222222222223,2.0436111111111113) charging behavior.
# (7346, 15)
# working on user with 47 total_capacity, 7.4 rate of charge, and (7.356944444444444,2.1866666666666665) charging behavior.
# (7376, 15)
# working on user with 109 total_capacity, 22 rate of charge, and (6.7988888888888885,2.073611111111111) charging behavior.
# (7406, 15)
# working on user with 77 total_capacity, 22 rate of charge, and (8.159444444444444,2.0655555555555556) charging behavior.
# (7436, 15)
# working on user with 120 total_capacity, 7.4 rate of charge, and (6.184722222222222,2.1241666666666665) charging behavior.
# (7466, 15)
# working on user with 73 total_capacity, 22 rate of charge, and (6.803055555555556,2.1205555555555557) charging behavior.
# (7496, 15)
# working on user with 97 total_capacity, 11 rate of charge, and (6.850833333333333,2.0252777777777777) charging behavior.
# (7526, 15)
# working on user with 81 total_capacity, 22 rate of charge, and (7.832222222222223,2.0116666666666667) charging behavior.
# (7556, 15)
# working on user with 32 total_capacity, 22 rate of charge, and (6.655277777777778,2.164722222222222) charging behavior.
# (7586, 15)
# working on user with 95 total_capacity, 22 rate of charge, and (7.188055555555556,1.9791666666666667) charging behavior.
# (7616, 15)
# working on user with 36 total_capacity, 22 rate of charge, and (6.7425,2.035) charging behavior.
# (7646, 15)
# working on user with 56 total_capacity, 11 rate of charge, and (6.955277777777778,2.0861111111111112) charging behavior.
# (7676, 15)
# working on user with 73 total_capacity, 22 rate of charge, and (8.013055555555555,2.1080555555555556) charging behavior.
# (7706, 15)
# working on user with 114 total_capacity, 7.4 rate of charge, and (7.998333333333333,1.948888888888889) charging behavior.
# (7736, 15)
# working on user with 35 total_capacity, 22 rate of charge, and (6.352222222222222,2.1694444444444443) charging behavior.
# (7766, 15)
# working on user with 35 total_capacity, 7.4 rate of charge, and (6.590833333333333,2.0591666666666666) charging behavior.
# (7796, 15)
# working on user with 71 total_capacity, 11 rate of charge, and (6.0008333333333335,1.925) charging behavior.
# (7826, 15)
# working on user with 83 total_capacity, 7.4 rate of charge, and (7.795277777777778,2.1433333333333335) charging behavior.
# (7856, 15)
# working on user with 62 total_capacity, 11 rate of charge, and (6.663888888888889,2.1591666666666667) charging behavior.
# (7886, 15)
# working on user with 110 total_capacity, 22 rate of charge, and (7.1194444444444445,2.1302777777777777) charging behavior.
# (7916, 15)
# working on user with 72 total_capacity, 22 rate of charge, and (5.768888888888889,2.046111111111111) charging behavior.
# (7946, 15)
# working on user with 43 total_capacity, 7.4 rate of charge, and (6.473055555555556,1.9908333333333332) charging behavior.
# (7976, 15)
# working on user with 80 total_capacity, 22 rate of charge, and (8.195833333333333,2.005) charging behavior.
# (8006, 15)
# working on user with 41 total_capacity, 22 rate of charge, and (6.2283333333333335,2.169722222222222) charging behavior.
# (8036, 15)
# working on user with 91 total_capacity, 22 rate of charge, and (6.1675,2.0277777777777777) charging behavior.
# (8066, 15)
# working on user with 22 total_capacity, 11 rate of charge, and (6.3277777777777775,2.0205555555555557) charging behavior.
# (8096, 15)
# working on user with 21 total_capacity, 11 rate of charge, and (6.998611111111111,1.9130555555555555) charging behavior.
# (8126, 15)
# working on user with 119 total_capacity, 11 rate of charge, and (8.09,2.0322222222222224) charging behavior.
# (8156, 15)
# working on user with 118 total_capacity, 7.4 rate of charge, and (6.7027777777777775,1.9255555555555555) charging behavior.
# (8186, 15)
# working on user with 29 total_capacity, 11 rate of charge, and (7.723611111111111,2.036388888888889) charging behavior.
# (8216, 15)
# working on user with 107 total_capacity, 11 rate of charge, and (5.5697222222222225,1.9675) charging behavior.
# (8246, 15)
# working on user with 121 total_capacity, 7.4 rate of charge, and (5.7225,2.18) charging behavior.
# (8276, 15)
# working on user with 88 total_capacity, 7.4 rate of charge, and (7.958888888888889,2.1075) charging behavior.
# (8306, 15)
# working on user with 74 total_capacity, 7.4 rate of charge, and (6.014722222222222,2.071388888888889) charging behavior.
# (8335, 15)
# working on user with 29 total_capacity, 7.4 rate of charge, and (5.7188888888888885,1.9269444444444443) charging behavior.
# (8365, 15)
# working on user with 56 total_capacity, 11 rate of charge, and (8.085555555555555,2.1175) charging behavior.
# (8395, 15)
# working on user with 46 total_capacity, 7.4 rate of charge, and (5.975,1.9766666666666666) charging behavior.
# (8425, 15)
# working on user with 35 total_capacity, 11 rate of charge, and (7.1525,2.047222222222222) charging behavior.
# (8455, 15)
# working on user with 70 total_capacity, 7.4 rate of charge, and (7.918055555555555,2.1991666666666667) charging behavior.
# (8485, 15)
# working on user with 53 total_capacity, 11 rate of charge, and (7.390555555555555,2.058333333333333) charging behavior.
# (8515, 15)
# working on user with 116 total_capacity, 22 rate of charge, and (7.267777777777778,2.131388888888889) charging behavior.
# (8545, 15)
# working on user with 55 total_capacity, 22 rate of charge, and (6.480833333333333,2.145) charging behavior.
# (8575, 15)
# working on user with 32 total_capacity, 7.4 rate of charge, and (6.363333333333333,2.1702777777777778) charging behavior.
# (8605, 15)
# working on user with 98 total_capacity, 7.4 rate of charge, and (6.819444444444445,2.0633333333333335) charging behavior.
# (8635, 15)
# working on user with 25 total_capacity, 22 rate of charge, and (6.432777777777778,2.0327777777777776) charging behavior.
# (8665, 15)
# working on user with 86 total_capacity, 7.4 rate of charge, and (5.663055555555555,1.9538888888888888) charging behavior.
# (8695, 15)
# working on user with 58 total_capacity, 11 rate of charge, and (5.6325,2.0322222222222224) charging behavior.
# (8725, 15)
# working on user with 65 total_capacity, 11 rate of charge, and (6.539166666666667,2.1491666666666664) charging behavior.
# (8755, 15)
# working on user with 62 total_capacity, 22 rate of charge, and (6.9558333333333335,1.9658333333333333) charging behavior.
# (8785, 15)
# working on user with 55 total_capacity, 11 rate of charge, and (7.539444444444444,2.0380555555555557) charging behavior.
# (8815, 15)
# working on user with 58 total_capacity, 7.4 rate of charge, and (7.515,1.9280555555555556) charging behavior.
# (8845, 15)
# working on user with 89 total_capacity, 22 rate of charge, and (6.385,2.0816666666666666) charging behavior.
# (8875, 15)
# working on user with 52 total_capacity, 22 rate of charge, and (8.1025,2.1191666666666666) charging behavior.
# (8905, 15)
# working on user with 56 total_capacity, 11 rate of charge, and (7.177777777777778,2.1286111111111112) charging behavior.
# (8935, 15)
# working on user with 27 total_capacity, 22 rate of charge, and (6.186388888888889,2.003888888888889) charging behavior.
# (8965, 15)
# working on user with 107 total_capacity, 11 rate of charge, and (7.978055555555556,2.0141666666666667) charging behavior.
# (8995, 15)
# working on user with 66 total_capacity, 11 rate of charge, and (6.403333333333333,1.913888888888889) charging behavior.
# (9025, 15)
# working on user with 101 total_capacity, 7.4 rate of charge, and (8.312777777777777,2.140833333333333) charging behavior.
# (9055, 15)
# working on user with 92 total_capacity, 22 rate of charge, and (5.730555555555555,1.9308333333333334) charging behavior.
# (9085, 15)
# working on user with 111 total_capacity, 7.4 rate of charge, and (7.288611111111111,2.1483333333333334) charging behavior.
# (9115, 15)
# working on user with 114 total_capacity, 22 rate of charge, and (7.453333333333333,2.043888888888889) charging behavior.
# (9145, 15)
# working on user with 100 total_capacity, 11 rate of charge, and (5.9847222222222225,1.9472222222222222) charging behavior.
# (9175, 15)
# working on user with 37 total_capacity, 22 rate of charge, and (5.9430555555555555,1.9738888888888888) charging behavior.
# (9205, 15)
# working on user with 47 total_capacity, 7.4 rate of charge, and (6.4325,1.9819444444444445) charging behavior.
# (9235, 15)
# working on user with 26 total_capacity, 22 rate of charge, and (6.775833333333333,2.214722222222222) charging behavior.
# (9265, 15)
# working on user with 60 total_capacity, 22 rate of charge, and (5.719444444444444,2.004166666666667) charging behavior.
# (9295, 15)
# working on user with 62 total_capacity, 22 rate of charge, and (7.754166666666666,2.048611111111111) charging behavior.
# (9325, 15)
# working on user with 47 total_capacity, 22 rate of charge, and (7.02,2.026111111111111) charging behavior.
# (9355, 15)
# working on user with 51 total_capacity, 11 rate of charge, and (6.858611111111111,1.9994444444444444) charging behavior.
# (9385, 15)
# working on user with 81 total_capacity, 7.4 rate of charge, and (6.328611111111111,2.1911111111111112) charging behavior.
# (9415, 15)
# working on user with 48 total_capacity, 11 rate of charge, and (7.999722222222222,1.9705555555555556) charging behavior.
# (9445, 15)
# working on user with 63 total_capacity, 11 rate of charge, and (7.988888888888889,2.013333333333333) charging behavior.
# (9475, 15)
# working on user with 69 total_capacity, 7.4 rate of charge, and (7.031666666666666,1.896111111111111) charging behavior.
# (9505, 15)
# working on user with 63 total_capacity, 7.4 rate of charge, and (7.261666666666667,2.2205555555555554) charging behavior.
# (9535, 15)
# working on user with 121 total_capacity, 7.4 rate of charge, and (7.350555555555555,2.194166666666667) charging behavior.
# (9565, 15)
# working on user with 81 total_capacity, 11 rate of charge, and (8.025555555555556,2.153888888888889) charging behavior.
# (9595, 15)
# working on user with 97 total_capacity, 22 rate of charge, and (6.874722222222222,1.9205555555555556) charging behavior.
# (9625, 15)
# working on user with 71 total_capacity, 11 rate of charge, and (6.535833333333334,2.111388888888889) charging behavior.
# (9655, 15)
# working on user with 111 total_capacity, 7.4 rate of charge, and (5.6375,2.0625) charging behavior.
# (9685, 15)
# working on user with 67 total_capacity, 7.4 rate of charge, and (7.713055555555556,1.9005555555555556) charging behavior.
# (9715, 15)
# working on user with 39 total_capacity, 7.4 rate of charge, and (8.136388888888888,1.9305555555555556) charging behavior.
# (9745, 15)
# working on user with 114 total_capacity, 7.4 rate of charge, and (6.194444444444445,2.1930555555555555) charging behavior.
# (9775, 15)
# working on user with 77 total_capacity, 11 rate of charge, and (7.447222222222222,2.178611111111111) charging behavior.
# (9805, 15)
# working on user with 91 total_capacity, 7.4 rate of charge, and (7.418611111111111,2.1969444444444446) charging behavior.
# (9835, 15)
# working on user with 34 total_capacity, 11 rate of charge, and (5.826666666666667,2.0155555555555558) charging behavior.
# (9865, 15)
# working on user with 76 total_capacity, 22 rate of charge, and (8.188333333333333,1.9730555555555556) charging behavior.
# (9895, 15)
# working on user with 54 total_capacity, 11 rate of charge, and (8.081666666666667,1.8888888888888888) charging behavior.
# (9925, 15)
# working on user with 64 total_capacity, 7.4 rate of charge, and (6.1722222222222225,1.9525) charging behavior.
# (9955, 15)
# working on user with 26 total_capacity, 11 rate of charge, and (7.424722222222222,1.9) charging behavior.
# (9985, 15)
# working on user with 97 total_capacity, 11 rate of charge, and (7.085833333333333,1.89) charging behavior.
# (10015, 15)
# working on user with 119 total_capacity, 22 rate of charge, and (8.332222222222223,1.9633333333333334) charging behavior.
# (10045, 15)
# working on user with 52 total_capacity, 11 rate of charge, and (5.797777777777778,2.1772222222222224) charging behavior.
# (10075, 15)
# working on user with 81 total_capacity, 7.4 rate of charge, and (5.583888888888889,2.1005555555555557) charging behavior.
# (10105, 15)
# working on user with 46 total_capacity, 11 rate of charge, and (5.594444444444444,2.161111111111111) charging behavior.
# (10135, 15)
# working on user with 85 total_capacity, 11 rate of charge, and (6.222777777777778,1.966388888888889) charging behavior.
# (10165, 15)
# working on user with 106 total_capacity, 7.4 rate of charge, and (8.080277777777777,2.029166666666667) charging behavior.
# (10195, 15)
# working on user with 45 total_capacity, 11 rate of charge, and (7.273888888888889,2.0875) charging behavior.
# (10225, 15)
# working on user with 101 total_capacity, 22 rate of charge, and (7.236666666666666,2.136111111111111) charging behavior.
# (10255, 15)
# working on user with 90 total_capacity, 11 rate of charge, and (7.95,2.0283333333333333) charging behavior.
# (10285, 15)
# working on user with 43 total_capacity, 11 rate of charge, and (6.649444444444445,1.9519444444444445) charging behavior.
# (10315, 15)
# working on user with 68 total_capacity, 7.4 rate of charge, and (6.070555555555556,1.9591666666666667) charging behavior.
# (10345, 15)
# working on user with 92 total_capacity, 7.4 rate of charge, and (6.730555555555555,2.167777777777778) charging behavior.
# (10375, 15)
# working on user with 93 total_capacity, 22 rate of charge, and (7.815,2.0927777777777776) charging behavior.
# (10405, 15)
# working on user with 114 total_capacity, 22 rate of charge, and (5.948055555555555,1.9461111111111111) charging behavior.
# (10435, 15)
# working on user with 110 total_capacity, 11 rate of charge, and (7.7875,2.2030555555555558) charging behavior.
# (10465, 15)
# working on user with 103 total_capacity, 11 rate of charge, and (7.347222222222222,2.140277777777778) charging behavior.
# (10495, 15)
# working on user with 34 total_capacity, 22 rate of charge, and (5.8275,2.0813888888888887) charging behavior.
# (10525, 15)
# working on user with 74 total_capacity, 22 rate of charge, and (6.855833333333333,2.1997222222222224) charging behavior.
# (10555, 15)
# working on user with 46 total_capacity, 7.4 rate of charge, and (5.963333333333333,1.9625) charging behavior.
# (10585, 15)
# working on user with 43 total_capacity, 7.4 rate of charge, and (7.376388888888889,2.1780555555555554) charging behavior.
# (10615, 15)
# working on user with 82 total_capacity, 22 rate of charge, and (7.890833333333333,2.0083333333333333) charging behavior.
# (10645, 15)
# working on user with 87 total_capacity, 22 rate of charge, and (5.931388888888889,2.076388888888889) charging behavior.
# (10674, 15)
# working on user with 58 total_capacity, 11 rate of charge, and (7.651944444444444,1.991111111111111) charging behavior.
# (10704, 15)
# working on user with 121 total_capacity, 22 rate of charge, and (6.83,2.0633333333333335) charging behavior.
# (10734, 15)
# working on user with 47 total_capacity, 11 rate of charge, and (6.4447222222222225,2.0597222222222222) charging behavior.
# (10764, 15)
# working on user with 60 total_capacity, 7.4 rate of charge, and (6.599444444444444,2.1030555555555557) charging behavior.
# (10794, 15)
# working on user with 67 total_capacity, 7.4 rate of charge, and (5.885833333333333,1.9380555555555556) charging behavior.
# (10824, 15)
# working on user with 51 total_capacity, 22 rate of charge, and (6.695555555555556,2.0375) charging behavior.
# (10854, 15)
# working on user with 81 total_capacity, 22 rate of charge, and (6.108333333333333,2.093611111111111) charging behavior.
# (10884, 15)
# working on user with 81 total_capacity, 22 rate of charge, and (6.958055555555555,2.2066666666666666) charging behavior.
# (10914, 15)
# working on user with 31 total_capacity, 22 rate of charge, and (7.7775,1.9977777777777779) charging behavior.
# (10944, 15)
# working on user with 32 total_capacity, 22 rate of charge, and (6.830555555555556,2.178888888888889) charging behavior.
# (10974, 15)
# working on user with 54 total_capacity, 11 rate of charge, and (8.12861111111111,2.0080555555555555) charging behavior.
# (11004, 15)
# working on user with 61 total_capacity, 22 rate of charge, and (6.4775,1.9733333333333334) charging behavior.
# (11034, 15)
# working on user with 54 total_capacity, 22 rate of charge, and (6.8197222222222225,2.1658333333333335) charging behavior.
# (11064, 15)
# working on user with 22 total_capacity, 22 rate of charge, and (8.18,2.191388888888889) charging behavior.
# (11094, 15)
# working on user with 67 total_capacity, 22 rate of charge, and (6.611666666666666,2.21) charging behavior.
# (11124, 15)
# working on user with 121 total_capacity, 7.4 rate of charge, and (6.050277777777778,2.2144444444444447) charging behavior.
# (11154, 15)
# ...
# (26323, 15)
# working on user with 23 total_capacity, 11 rate of charge, and (6.911111111111111,2.066388888888889) charging behavior.
# (26353, 15)
# working on user with 86 total_capacity, 22 rate of charge, and (6.873055555555555,2.0469444444444442) charging behavior.
# (26383, 15)
# working on user with 38 total_capacity, 11 rate of charge, and (6.625555555555556,2.185) charging behavior.
# (26413, 15)
# working on user with 21 total_capacity, 22 rate of charge, and (7.508611111111111,1.9058333333333333) charging behavior.
# (26443, 15)
# working on user with 110 total_capacity, 11 rate of charge, and (8.285,1.8958333333333333) charging behavior.
# (26473, 15)
# working on user with 74 total_capacity, 11 rate of charge, and (7.456666666666667,2.207222222222222) charging behavior.
# (26503, 15)
# working on user with 82 total_capacity, 7.4 rate of charge, and (5.632777777777778,1.9291666666666667) charging behavior.
# (26533, 15)
# working on user with 39 total_capacity, 7.4 rate of charge, and (7.299166666666666,1.8891666666666667) charging behavior.
# (26563, 15)
# working on user with 35 total_capacity, 7.4 rate of charge, and (6.292777777777777,1.9641666666666666) charging behavior.
# (26592, 15)
# working on user with 87 total_capacity, 22 rate of charge, and (7.58,2.02) charging behavior.
# (26622, 15)
# working on user with 86 total_capacity, 11 rate of charge, and (7.311111111111111,1.9644444444444444) charging behavior.
# (26652, 15)
# working on user with 118 total_capacity, 7.4 rate of charge, and (6.794722222222222,2.107222222222222) charging behavior.
# (26682, 15)
# working on user with 122 total_capacity, 7.4 rate of charge, and (7.676944444444445,2.202777777777778) charging behavior.
# (26712, 15)
# working on user with 28 total_capacity, 11 rate of charge, and (6.231944444444444,2.105) charging behavior.
# (26742, 15)
# working on user with 114 total_capacity, 11 rate of charge, and (6.0633333333333335,2.069166666666667) charging behavior.
# (26772, 15)
# working on user with 88 total_capacity, 22 rate of charge, and (6.996388888888889,1.9708333333333334) charging behavior.
# (26802, 15)
# working on user with 99 total_capacity, 22 rate of charge, and (5.926111111111111,1.9583333333333333) charging behavior.
# (26832, 15)
# working on user with 46 total_capacity, 7.4 rate of charge, and (7.299722222222222,2.1994444444444445) charging behavior.
# (26862, 15)
# working on user with 99 total_capacity, 7.4 rate of charge, and (6.96,2.0966666666666667) charging behavior.
# (26892, 15)
# working on user with 70 total_capacity, 11 rate of charge, and (8.160277777777777,1.9930555555555556) charging behavior.
# (26922, 15)
# working on user with 87 total_capacity, 11 rate of charge, and (5.730833333333333,2.1594444444444445) charging behavior.
# (26952, 15)
# working on user with 59 total_capacity, 7.4 rate of charge, and (6.273055555555556,1.9761111111111112) charging behavior.
# (26982, 15)
# working on user with 45 total_capacity, 7.4 rate of charge, and (8.174444444444445,2.2169444444444446) charging behavior.
# (27012, 15)
# working on user with 89 total_capacity, 22 rate of charge, and (6.875555555555556,2.1691666666666665) charging behavior.
# (27042, 15)
# working on user with 95 total_capacity, 22 rate of charge, and (6.299166666666666,2.043888888888889) charging behavior.
# (27072, 15)
# working on user with 43 total_capacity, 22 rate of charge, and (7.54,1.93) charging behavior.
# (27102, 15)
# working on user with 69 total_capacity, 7.4 rate of charge, and (8.153888888888888,1.9583333333333333) charging behavior.
# (27132, 15)
# working on user with 35 total_capacity, 22 rate of charge, and (6.211111111111111,2.0677777777777777) charging behavior.
# (27162, 15)
# working on user with 77 total_capacity, 22 rate of charge, and (5.600555555555555,2.096388888888889) charging behavior.
# (27192, 15)
# working on user with 77 total_capacity, 7.4 rate of charge, and (5.789166666666667,1.9536111111111112) charging behavior.
# (27222, 15)
# working on user with 92 total_capacity, 7.4 rate of charge, and (5.854444444444445,2.0241666666666664) charging behavior.
# (27252, 15)
# working on user with 74 total_capacity, 7.4 rate of charge, and (8.091111111111111,2.1094444444444442) charging behavior.
# (27282, 15)
# working on user with 100 total_capacity, 22 rate of charge, and (6.183611111111111,2.0302777777777776) charging behavior.
# (27312, 15)
# working on user with 27 total_capacity, 7.4 rate of charge, and (7.305833333333333,1.9213888888888888) charging behavior.
# (27342, 15)
# working on user with 24 total_capacity, 7.4 rate of charge, and (6.645,2.1480555555555556) charging behavior.
# (27372, 15)
# working on user with 59 total_capacity, 7.4 rate of charge, and (5.626111111111111,1.9325) charging behavior.
# (27402, 15)
# working on user with 91 total_capacity, 22 rate of charge, and (5.5761111111111115,2.189722222222222) charging behavior.
# (27431, 15)
# working on user with 42 total_capacity, 11 rate of charge, and (6.916666666666667,1.97) charging behavior.
# (27461, 15)
# working on user with 83 total_capacity, 22 rate of charge, and (8.15,2.0855555555555556) charging behavior.
# (27491, 15)
# working on user with 53 total_capacity, 11 rate of charge, and (7.255833333333333,1.8997222222222223) charging behavior.
# (27521, 15)
# working on user with 123 total_capacity, 22 rate of charge, and (7.204444444444444,2.0819444444444444) charging behavior.
# (27551, 15)
# working on user with 99 total_capacity, 7.4 rate of charge, and (6.751944444444445,2.080277777777778) charging behavior.
# (27581, 15)
# working on user with 105 total_capacity, 11 rate of charge, and (6.033333333333333,1.906111111111111) charging behavior.
# (27611, 15)
# working on user with 66 total_capacity, 11 rate of charge, and (6.7411111111111115,2.0375) charging behavior.
# (27641, 15)
# working on user with 122 total_capacity, 7.4 rate of charge, and (8.209444444444445,2.131388888888889) charging behavior.
# (27671, 15)
# working on user with 88 total_capacity, 7.4 rate of charge, and (7.019722222222223,1.9555555555555555) charging behavior.
# (27701, 15)
# working on user with 84 total_capacity, 22 rate of charge, and (6.985555555555556,2.171388888888889) charging behavior.
# (27731, 15)
# working on user with 67 total_capacity, 22 rate of charge, and (5.8661111111111115,2.122777777777778) charging behavior.
# (27761, 15)
# working on user with 45 total_capacity, 11 rate of charge, and (7.5441666666666665,2.0169444444444444) charging behavior.
# (27791, 15)
# working on user with 22 total_capacity, 22 rate of charge, and (6.589722222222222,1.8919444444444444) charging behavior.
# (27821, 15)
# working on user with 83 total_capacity, 7.4 rate of charge, and (7.266944444444444,1.9552777777777777) charging behavior.
# (27851, 15)
# working on user with 38 total_capacity, 22 rate of charge, and (7.146388888888889,2.0119444444444445) charging behavior.
# (27881, 15)
# working on user with 67 total_capacity, 22 rate of charge, and (7.886666666666667,1.9666666666666666) charging behavior.
# (27911, 15)
# working on user with 33 total_capacity, 22 rate of charge, and (6.361944444444444,1.9) charging behavior.
# (27941, 15)
# working on user with 100 total_capacity, 7.4 rate of charge, and (8.029722222222222,2.129166666666667) charging behavior.
# (27971, 15)
# working on user with 107 total_capacity, 22 rate of charge, and (7.534166666666667,2.1744444444444446) charging behavior.
# (28001, 15)
# working on user with 91 total_capacity, 7.4 rate of charge, and (7.9094444444444445,1.9294444444444445) charging behavior.
# (28031, 15)
# working on user with 66 total_capacity, 22 rate of charge, and (5.686111111111111,2.0366666666666666) charging behavior.
# (28061, 15)
# working on user with 28 total_capacity, 11 rate of charge, and (6.225833333333333,2.046111111111111) charging behavior.
# (28091, 15)
# working on user with 91 total_capacity, 11 rate of charge, and (6.134444444444444,1.9433333333333334) charging behavior.
# (28121, 15)
# working on user with 55 total_capacity, 22 rate of charge, and (7.489722222222222,1.9636111111111112) charging behavior.
# (28151, 15)
# working on user with 88 total_capacity, 11 rate of charge, and (6.473888888888889,1.9566666666666668) charging behavior.
# (28181, 15)
# working on user with 106 total_capacity, 22 rate of charge, and (7.881388888888889,2.005) charging behavior.
# (28211, 15)
# working on user with 22 total_capacity, 11 rate of charge, and (7.654166666666667,1.9608333333333334) charging behavior.
# (28241, 15)
# working on user with 48 total_capacity, 11 rate of charge, and (7.290555555555556,2.0766666666666667) charging behavior.
# (28271, 15)
# working on user with 77 total_capacity, 22 rate of charge, and (6.833055555555555,2.0527777777777776) charging behavior.
# (28301, 15)
# working on user with 79 total_capacity, 11 rate of charge, and (7.246666666666667,2.066666666666667) charging behavior.
# (28331, 15)
# working on user with 49 total_capacity, 22 rate of charge, and (6.681666666666667,2.145) charging behavior.
# (28361, 15)
# working on user with 29 total_capacity, 7.4 rate of charge, and (7.985555555555556,2.122777777777778) charging behavior.
# (28391, 15)
# working on user with 59 total_capacity, 11 rate of charge, and (7.191666666666666,2.0908333333333333) charging behavior.
# (28421, 15)
# working on user with 107 total_capacity, 11 rate of charge, and (8.163333333333334,2.1733333333333333) charging behavior.
# (28451, 15)
# working on user with 27 total_capacity, 7.4 rate of charge, and (6.178055555555556,2.0744444444444445) charging behavior.
# (28481, 15)
# working on user with 105 total_capacity, 7.4 rate of charge, and (7.954444444444444,2.1580555555555554) charging behavior.
# (28511, 15)
# working on user with 93 total_capacity, 7.4 rate of charge, and (6.606111111111111,2.113611111111111) charging behavior.
# (28541, 15)
# working on user with 71 total_capacity, 22 rate of charge, and (7.763888888888889,2.1661111111111113) charging behavior.
# (28571, 15)
# working on user with 53 total_capacity, 7.4 rate of charge, and (7.11,2.015277777777778) charging behavior.
# (28601, 15)
# working on user with 55 total_capacity, 7.4 rate of charge, and (7.358611111111111,2.0816666666666666) charging behavior.
# (28631, 15)
# working on user with 25 total_capacity, 11 rate of charge, and (6.860277777777778,2.2194444444444446) charging behavior.
# (28661, 15)
# working on user with 29 total_capacity, 11 rate of charge, and (7.696111111111111,1.9597222222222221) charging behavior.
# (28691, 15)
# working on user with 25 total_capacity, 22 rate of charge, and (7.408333333333333,2.0330555555555554) charging behavior.
# (28721, 15)
# working on user with 67 total_capacity, 22 rate of charge, and (7.094166666666666,1.97) charging behavior.
# (28751, 15)
# working on user with 23 total_capacity, 22 rate of charge, and (7.341388888888889,2.2022222222222223) charging behavior.
# (28781, 15)
# working on user with 102 total_capacity, 22 rate of charge, and (8.007222222222222,2.158611111111111) charging behavior.
# (28811, 15)
# working on user with 110 total_capacity, 22 rate of charge, and (8.119722222222222,2.1494444444444443) charging behavior.
# (28841, 15)
# working on user with 107 total_capacity, 22 rate of charge, and (6.2975,2.0180555555555557) charging behavior.
# (28871, 15)
# working on user with 53 total_capacity, 7.4 rate of charge, and (6.036944444444444,1.9672222222222222) charging behavior.
# (28901, 15)
# working on user with 35 total_capacity, 22 rate of charge, and (8.247222222222222,1.9622222222222223) charging behavior.
# (28931, 15)
# working on user with 120 total_capacity, 11 rate of charge, and (5.571666666666666,1.9444444444444444) charging behavior.
# (28961, 15)
# working on user with 68 total_capacity, 7.4 rate of charge, and (6.2813888888888885,2.0794444444444444) charging behavior.
# (28991, 15)
# working on user with 51 total_capacity, 11 rate of charge, and (6.542777777777777,2.0555555555555554) charging behavior.
# (29021, 15)
# working on user with 63 total_capacity, 11 rate of charge, and (7.048611111111111,2.172222222222222) charging behavior.
# (29051, 15)
# working on user with 60 total_capacity, 11 rate of charge, and (6.818611111111111,2.0322222222222224) charging behavior.
# (29081, 15)
# working on user with 85 total_capacity, 11 rate of charge, and (6.592222222222222,2.0741666666666667) charging behavior.
# (29111, 15)
# working on user with 79 total_capacity, 7.4 rate of charge, and (6.933611111111111,1.9591666666666667) charging behavior.
# (29141, 15)
# working on user with 93 total_capacity, 22 rate of charge, and (5.833888888888889,1.8933333333333333) charging behavior.
# (29171, 15)
# working on user with 122 total_capacity, 22 rate of charge, and (5.7825,1.9916666666666667) charging behavior.
# (29201, 15)
# working on user with 103 total_capacity, 22 rate of charge, and (5.6025,2.145) charging behavior.
# (29231, 15)
# working on user with 44 total_capacity, 22 rate of charge, and (7.527777777777778,1.9333333333333333) charging behavior.
# (29261, 15)
# working on user with 93 total_capacity, 22 rate of charge, and (7.386666666666667,2.091388888888889) charging behavior.
# (29291, 15)
# working on user with 58 total_capacity, 7.4 rate of charge, and (7.8244444444444445,2.2080555555555557) charging behavior.
# (29321, 15)
# working on user with 51 total_capacity, 22 rate of charge, and (7.507777777777778,2.0861111111111112) charging behavior.
# (29351, 15)
# working on user with 70 total_capacity, 7.4 rate of charge, and (7.307222222222222,2.0458333333333334) charging behavior.
# (29381, 15)
# working on user with 51 total_capacity, 11 rate of charge, and (6.3116666666666665,2.1755555555555555) charging behavior.
# (29411, 15)
# working on user with 21 total_capacity, 11 rate of charge, and (7.515833333333333,1.9605555555555556) charging behavior.
# (29441, 15)
# working on user with 32 total_capacity, 7.4 rate of charge, and (6.990555555555556,2.2194444444444446) charging behavior.
# (29471, 15)
# working on user with 80 total_capacity, 22 rate of charge, and (7.783888888888889,2.183333333333333) charging behavior.
# (29501, 15)
# working on user with 48 total_capacity, 7.4 rate of charge, and (7.697222222222222,2.120277777777778) charging behavior.
# (29531, 15)
# working on user with 80 total_capacity, 7.4 rate of charge, and (8.047777777777778,2.1591666666666667) charging behavior.
# (29561, 15)
# working on user with 32 total_capacity, 22 rate of charge, and (6.0125,2.111666666666667) charging behavior.
# (29591, 15)
# working on user with 48 total_capacity, 22 rate of charge, and (8.30861111111111,2.1397222222222223) charging behavior.
# (29621, 15)
# working on user with 85 total_capacity, 7.4 rate of charge, and (8.052222222222222,2.1780555555555554) charging behavior.
# (29651, 15)
# working on user with 108 total_capacity, 11 rate of charge, and (7.154166666666667,2.2180555555555554) charging behavior.
# (29681, 15)
# working on user with 111 total_capacity, 22 rate of charge, and (8.278055555555556,2.033611111111111) charging behavior.
# (29711, 15)
# working on user with 72 total_capacity, 7.4 rate of charge, and (8.186666666666667,2.1927777777777777) charging behavior.
# (29741, 15)
# working on user with 34 total_capacity, 7.4 rate of charge, and (7.279722222222222,1.9419444444444445) charging behavior.
# (29771, 15)
# working on user with 113 total_capacity, 7.4 rate of charge, and (7.799722222222222,1.9116666666666666) charging behavior.
# (29801, 15)
# working on user with 63 total_capacity, 22 rate of charge, and (6.423611111111111,2.196111111111111) charging behavior.
# (29831, 15)
# working on user with 83 total_capacity, 7.4 rate of charge, and (5.556388888888889,2.0894444444444447) charging behavior.
# (29860, 15)
# working on user with 37 total_capacity, 7.4 rate of charge, and (7.194166666666667,2.0994444444444444) charging behavior.
# (29890, 15)
# working on user with 94 total_capacity, 11 rate of charge, and (7.051944444444445,2.125) charging behavior.
# (29920, 15)
# working on user with 66 total_capacity, 7.4 rate of charge, and (6.009166666666666,1.9402777777777778) charging behavior.
# (29950, 15)
# working on user with 122 total_capacity, 7.4 rate of charge, and (7.019166666666667,2.180833333333333) charging behavior.
# (29980, 15)

# %%
all_users.to_csv('dummy_evaluation_data.csv')

# %%
all_users.shape
# Out:
# (29980, 15)
